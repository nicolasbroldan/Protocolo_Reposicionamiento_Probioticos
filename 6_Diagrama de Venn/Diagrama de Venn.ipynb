# %% [markdown]
# ## Disease/Drugs

# %%
from matplotlib_venn import venn3
import matplotlib.pyplot as plt

# Definir los conjuntos
A = {
    "Inflammation", "Pneumonia", "Reperfusion Injury", "Asthma", "Psoriasis",
    "Juvenile arthritis", "Lymphoma", "Multiple Myeloma", "Virus Diaseases",
    "Myocardial Ischemia", "Arsenic Encephalopathy", "Cerebral Ischemia",
    "Dermatologic Disorders", "Marfan Syndrome", "Mammary Neoplasm", 
    "Bright Disease", "Cerebral Infraction", "Cerebral Thrombosis", 
    "Alveolitis", "Charcot-Marie-Tooth disease type 1D", 
    "Charcot-Marie-Tooth disease type 4E", "Nasopharyngeal carcinoma", 
    "Systemic-onset juvenile Idiopathic arthritis", 
    "Hereditary pediatric Behcet-like disease", 
    "Autosomal hyper-lgE syndrome", "Psoriatic arthritis",
    "Chronic limphoproliferative disorder of natural killer cells", 
    "STAT3-releated early-onset multisystem autoimmune disease", 
    "T-cell granular lymphocyte leukemia"
}

B = {
    "Epstein-Barr Virus Infections", "Kaposi Sarcoma", "Renal interstitial fibrosis",
    "Acute Myeloid Leukemia", "Vascular Diseases", "Duodenal Ulcer", 
    "Paroxysmal kinesigenic choreoathetosis", "Kidney Diseases", 
    "Ischemia of Kideney", "Non-Small Cell Lung Carcinoma", 
    "Pancreatic Neoplasm", "Cholestasis", "Hypermagnesemia", 
    "Isolated Michrophtalmia-Anophthalmia-Coloboma", "Nocturia", 
    "Mitochondrial Encephalopathy", "Stomach Neoplasm", "Hypomagnesmia", 
    "Conn Syndrome", "Bartter Syndrome", "Charcot-Marie-Tooth disease type 1D", 
    "Charcot-Marie-Tooth disease type 4E", 
    "Intermediate generalized junctional epidermolysis bullosa", 
    "Severe generalized junctional, epidermolysis bullosa", 
    "Exfoliative ichthyosis", "Kindler epidermolysis bullosa", 
    "Osteofibrous dysplasia", "Interstitial lung disease", "Nephrotic syndrome", 
    "Epidermolysis bullosa syndrome", 
    "UMOD-relaeted autosomal dominant tubointerstitial kidney disease", 
    "Cryptogenic multifocal ulcerous stenosing enteritis"
}

C = {
    "Malignant neoplasm of breast", "Carcinoma of bladder", "Bladder Neoplasm",
    "Malignant neoplasm of urinary bladder", "Reticulocyte count (procedure)", 
    "Adenomatous Poliposis Coli", "Malignant lymphoma, lymphocytic", 
    "Intermediate differentiation, diffuse", "Breast Carcinoma", 
    "Hydatidiform Mole Partial", "Diffuse arge B-Cell Lymphoma", 
    "Adrenocortical Adenoma", "Carcinoma of the head and Neck", "Insulinoma", 
    "Microcephaly With Chorioretinopathy", "Paroxysmal Nonkinesigenic Dyskinesia", 
    "Adrenocortical Carcinoma", "Multiple Endocrine Carcinoma", 
    "Multiple Endocrine Neoplasia", "Parathyroid Hyperplasia", "Glucagonoma", 
    "Osteopetrosis", "Autosomal dominant centronuclear myopathy", 
    "Homocystinuria due to methylene tetrahydrofolate reductase deficiency", 
    "Autosomal dominant spastic paraplegia type 12", 
    "Charcot-Marie-Tooth disease type 4G", "Multinucleated neurons",
    "Anhydramnios", "Renal dysplasia", "Cerebellar hypoplasia", 
    "Hydranencephaly syndrome", 
    "Non-spherocytic hemolytic anemia due to hexokinase deficiency",
    "Otospondylomegaepiphyseal dysplasia",
    "Mosaic variegated aneuploidy syndrome",
    "21q22.11q22.12 microdeletion syndrome",
    "Adult-onset autosomal dominant"
}

# Calcular las intersecciones
intersection_AB = A & B
intersection_AC = A & C
intersection_BC = B & C
intersection_ABC = A & B & C

# Imprimir los valores de las intersecciones
print("Intersección A ∩ B:", intersection_AB)
print("Intersección A ∩ C:", intersection_AC)
print("Intersección B ∩ C:", intersection_BC)
print("Intersección A ∩ B ∩ C:", intersection_ABC)

# Crear el diagrama de Venn
venn = venn3(
    subsets=(len(A - B - C), len(B - A - C), len(A & B - C), 
             len(C - A - B), len(A & C - B), len(B & C - A), len(A & B & C)),
    set_labels=("Bacillus", "Lactobacillus", "Propionibacterium")
)

# Personalizar el estilo
for subset in venn.subset_labels:
    if subset:  # Evitar etiquetas vacías
        subset.set_fontsize(10)

plt.title("Disease/Drugs")
plt.show()
# Out:
# Intersección A ∩ B: {'Charcot-Marie-Tooth disease type 4E', 'Charcot-Marie-Tooth disease type 1D'}
# Intersección A ∩ C: set()
# Intersección B ∩ C: set()
# Intersección A ∩ B ∩ C: set()

# %% [markdown]
# ## Ontologies

# %%
from matplotlib_venn import venn3
import matplotlib.pyplot as plt

# Definir los conjuntos A, B, C
A = {
    "Inflammatory Response", "Cytokine-Mediated Signaling Pathway", "Chemokine-Mediated Signaling Pathway", "Cellular Response To Chemokine",
    "Neutrophil Chemotaxis", "Granulocyte Chemotaxis", "Neutrophil Migration", "Cellular Response To Lipopolysaccharide", 
    "Cellular Response To Molecule Of Bacterial Origin", "Lymphocyte Chemotaxis", "Intracellular Organelle Lumen", 
    "Endocytic Vesicle Lumen", "Platelet Alpha Granule Lumen", "Platelet Alpha Granule", "Aggresome", 
    "Serine Protease Inhibitor Complex", "Endoplasmatic Reticulum Lumen", "Ficolin-1-Rich Granule Lumen", 
    "Serine-Type Endopeptidase Complex", "Secretory Granule Lumen", "Cytokine Activity", "Chemokine Activity", 
    "Chemokine Receptor Binding", "CXCR Chemokine Receptor Binding", "Receptor Ligand Activity", 
    "CCR Chemokine Receptor Binding", "Cytokyne Receptor Binding", "Growth Factor Activity", "C3HC4-type RING Finger Domain Binding",
    "Chemottractant Activity", "Arthritis", "Lung Disease", "Influenza", "Periodontitis", "Collagen disease", "Peritonitis", 
    "Gingivitis", "Brain Ischemia", "Human inmunodeficiency virus infectious disease", "Keratitis"
}

B = {
    "Cellular Response To Interleukin-1", "Positive Regulation Of Cellular Biosynthetic Process", "Cytokine-Mediated Signaling Pathway", 
    "Response To Heparin", "Positive Regulation Of Tau-Protein Kinase Activity", "Regulation Of Hormone Biosynthetic Process", 
    "Regulation Of Ketone Biosynthetic Process", "Positive Regulation Of Hormone Metabolic Process", "Regulation Of Entry Of Bacterium Into Host Cell", 
    "Regulation Of Cell Adhesion Molecule Production", "Nucleus", "Intracellular Membrane-Bounded Organelle", 
    "Double-Stranded Methylated DNA Binding", "Retinal Dehydrogenase Activity", "Cloride:Monoatomic Cation Symporter Activity", 
    "Potassium:Chloride Symporter Acivity", "Sodium:Chloride Symporter Activity", "Aldehyde Dehydrogenase (NAD+) Activity", 
    "Aldehyde Dehydrogenase [NAD(P)+] Activity", "CXCR Chemokine Receptor Binding", "Histone Acetyltransferase Binding", 
    "Oxidoreductase Activity. Acting On The Aldehyde Or Oxo Group Of Donors. NAD Or NADP As Acceptor", "Ocular hypotension", 
    "Chondrocalcinosis", "Matthew-Wood syndrome", "Hyperaldosteronism", "Polyhydramnios", "Microphthalmia", "Calcinosis", 
    "Hypokalemia", "Metabolic acidosis", "Cerebrovascular disease"
}

C = {
    "Regulation Of Cyclin-Dependent Protein Kinase Activity", "Regulation Of Cyclin-Dependent Protein Serine/Threonine Kinase Activity", 
    "Negative Regulation Of Phosphate Metabolic Process", "Mitotic Cell Cycle Phase Transition", "Cell Cycle G2/M Phase Transition", 
    "Regulation Of Protein Serine/Threonine Kinase Activity", "G2/M Transition Of Mitotic Cell Cycle", "Microtubule Nucleation", 
    "Water-Soluble Vitamin Metabolic Process", "Regulation Of Release Of Cytochrome C From Mitochondria", "Intracellular Organelle Lumen", 
    "Endocytic Vesicle Lumen", "Platelet Alpha Granule Lumen", "Platelet Alpha Granule", "Aggresome", 
    "Serine Protease Inhibitor Complex", "Endoplasmatic Reticulum Lumen", "Ficolin-1-Rich Granule Lumen", 
    "Serine-Type Endopeptidase Complex", "Secretory Granule Lumen", "Cyclin-Dependent Protein Serine/Threonine Kinase Regulator Activity", 
    "3'-5' Exonuclease Activity", "RNA Exonuclease Activity Producing 5'-Phosphomonoesters", "3'-5'-RNA Exonuclease Activity", 
    "Calcium Ion Biding", "Protein Kinase Regulator Activity", "Gamma-Tubulin Binding", "Protein Kinase Inhibitor Activity", 
    "Protein Serine/Threonine Kinase Inhibitor Activity", "Cyclin-Dependent Protein Serine/Threonine Kinase Inhibitor Activity", 
    "Bile Reflux", "Peutz-Jeghers syndrome", "Aarksog-Scott syndrome", "Osteopetrosis", "Specific Language Impairment", 
    "Otitis external", "Dandy-Walker syndrome", "Cholangiocarcinoma", "Silver-Russel syndrome", "Paroxysmal nocturnal hemoglobinuria"
}

# Calcular las intersecciones
intersection_AB = A & B
intersection_AC = A & C
intersection_BC = B & C
intersection_ABC = A & B & C

# Imprimir los valores de las intersecciones
print("Intersección A ∩ B:", intersection_AB)
print("Intersección A ∩ C:", intersection_AC)
print("Intersección B ∩ C:", intersection_BC)
print("Intersección A ∩ B ∩ C:", intersection_ABC)

# Crear el diagrama de Venn
venn = venn3(
    subsets=(len(A - B - C), len(B - A - C), len(A & B - C), 
             len(C - A - B), len(A & C - B), len(B & C - A), len(A & B & C)),
    set_labels=("Bacillus", "Lactobacillus", "Propionibacterium")
)

# Personalizar el estilo
for subset in venn.subset_labels:
    if subset:  # Evitar etiquetas vacías
        subset.set_fontsize(10)

plt.title("Ontologies")
plt.show()
# Out:
# Intersección A ∩ B: {'Cytokine-Mediated Signaling Pathway', 'CXCR Chemokine Receptor Binding'}
# Intersección A ∩ C: {'Serine Protease Inhibitor Complex', 'Serine-Type Endopeptidase Complex', 'Secretory Granule Lumen', 'Endoplasmatic Reticulum Lumen', 'Ficolin-1-Rich Granule Lumen', 'Intracellular Organelle Lumen', 'Platelet Alpha Granule Lumen', 'Endocytic Vesicle Lumen', 'Aggresome', 'Platelet Alpha Granule'}
# Intersección B ∩ C: set()
# Intersección A ∩ B ∩ C: set()

# %% [markdown]
# ## Pathways

# %%
from matplotlib_venn import venn3
import matplotlib.pyplot as plt
A = {
    "Proteins Involved in Atherosclerosis", "TLR2 Induced Synovial Fibroblast Activation in Rheumatoid Arthritis",
    "Proteins Involved in HIV Type 1 Infection", "Proteins Involved in Myocarditis", "Proteins Involved in Glomerulonephritis",
    "IL17 Signaling in Psoriasis", "ROS in Triggering Vascular Inflammation", "IL1B Expression Targets -> Nociception",
    "Cytokines Trigger Otitis Media", "Neutrophil Recruitment in Synovium in Gout", "TNF signaling pathway",
    "Rheumatoid arthritis", "Cytokine-cytokine receptor interaction", "Viral protein interaction with cytokine and cytokine receptor",
    "IL-17 signaling pathway", "Lipid and atherosclerosis", "Legionellosis", "Chemokine signaling pathway", "Pertussis",
    "Melatonin", "beta-Estradiol", "3-Phospo-D-glycerol Dihydrogen Phosphate", "NAD+", "Glyceraldehyde 3-Phosphate",
    "4-(N-Nitrosomethylamino)-1-(3-pyridyl)-1-butanone", "Dehydroepiandrosterone", "NADP+", "Estrone", "Retinoic Acid",
    "Interleukin-10 Signaling", "Chemokine Receptors Bind Chemokines", "Signaling By Interleukins",
    "Cytokine Signaling In Immune System", "Peptide Ligand-Binding Receptors", "Immune System",
    "Class A/1 (Rhodopsin-like Receptors)", "Interleukin-4 And Interleukin-13 Signaling", "Attenuation Phase",
    "Cercopithecine betaherpesvirus 5 chemokine vCXCL5", "Vaccinia virus chemokine binding protein",
    "Vaccina virus Ankara viral chemokine binding protein", "Cercopithecine betaherpes virus 5 chemokine vCXCL10",
    "Cowpox virus CrmD or CPXV221 protein", "Variola virus hypothetical protein",
    "Ectromelia virus ERPV tumor necrosis factor receptor", "Horsepox virus HSPV003 (Tumor necrosis factor receptor superfamily members)",
    "Human gammaherpesvirus8 K6"
}

B = {
    "Leukotriene Effect on Vascular Endothelial Cell Response", "IL1B Expression Targets -> Nociception",
    "Mast-Cells Activation in Atopic Dermatitis", "Hepatic Stellate Cells in non-Alcoholic Fatty Liver Disease",
    "Alveolar Epithelial Cell Dysfunction in COPD", "CXC Chemokine Receptor Signaling",
    "Proteins involved in Chronic Obstructive Pulmonary Disease", "Proteins Involved in Myocardial Ischemia",
    "CHRNA7 -> IL8 Production", "Proteins with Altered Expression in Pyelonephritis",
    "AGE-RAGE signaling pathway in diabetic complications", "Bladder cancer", "Malaria", "Legionellosis",
    "Retinol metabolism", "Epithelial cell signaling in Helicobacter pylori infection",
    "RIG-I-like receptor signaling pathway", "Pertussis", "GnRh signaling pathway", "Rheumatoid arthritis",
    "9-cis-Retinal", "Retinal", "Retinoic Acid", "NAD+", "Cation-coupled Chloride Cotransporters",
    "RA Biosynthesis Pathway", "ATF4 Activates Genes in Response To Endoplasmic Reticulum Stress",
    "PERK Regulates Gene Expression", "Signal Transduction", "Cytokine Signaling In Immune System",
    "NGF-stimulated Transcription", "Signaling By Retinoic Acid", "Interleukin-10 Signaling",
    "Chemokine Receptors Bind Chemokines", "Cercopithecine betaherpesvirus 5 chemokine vCXCL6",
    "Human papillomavirus 172 E7", "Human papillomavirus type 108 early protein E7",
    "Human papillomavirus type 82 E7", "Human papillomavirus 141 transforming protein",
    "Human papillomavirus type 13 E7", "Human papillomavirus type 144 transforming protein",
    "Human papillomavirus type 166 E7", "Human papillomavirus 19 early protein"
}

C = {
    "S/G2 Phase Transition", "EZH2 Methyltransferase Role in Cancer", "Cell Cycle Overview", "G2/M Phase Transition",
    "SCF/SKP2 Complex", "HPV E1 and E2 Expression in Early Phase of Cancer", "G1/S Phase Transition",
    "HPV E4 Contribution to Life Cycle of Virus and Cell", "FOXM1 Signaling in Prostate Cancer",
    "Genes with Mutations Associated with Osteopetrosis", "Cell cycle", "p53 signaling pathway", "Cellular senescence",
    "Glycerophospholipid metabolism", "Oocyte meiosis", "Fox0 signaling pathway", "Ubiquitin mediated proteolysis",
    "Human T-cell leukemia virus 1 infection", "Arachidonic acid metabolism", "Retinol metabolism",
    "Cell Cycle", "G2/M Transition", "Mitotic G2-G2/M Phases", "Cell Cycle Mitotic",
    "Aberrant Regulation Of Mitotic G1/S Transition in Cancer Due To RB1 Defects",
    "Cyclin D Associated Events in G1", "TPS 3 Regulates Transcription Of Cell Cycle Genes",
    "RHOBTB3 ATPase Cycle", "Mitotic Prometaphase", "Cyclin A/B1/B2 Associated Events During G2/M Transition",
    "Human betaherpesvirus 5 tegument serine/threonine protein kinase",
    "Vaccinia virus Ankara Serine/threonine-protein kinase 2",
    "Horsepox virus HSPV050 (Ser/Thr kinase; Provisional)",
    "Human alphaherpesvirus 1 serine/threonine protein kinase US3",
    "Macacine alphaherpesvirus 1 serine/threonine protein kinase US3",
    "Human gammaherpesvirus 8 ORF72", "Human alphaherpesvirus 2 serine/threonine protein kinase US3",
    "Macacine alphaherpesvirus 1 tegument serine/threonine protein kinase",
    "Human T-lymphotropic virus 3 envelope", "Human alphaherpesvirus 3 tegument serine/threonine protein kinase"
}

# Calcular las intersecciones
intersection_AB = A & B
intersection_AC = A & C
intersection_BC = B & C
intersection_ABC = A & B & C

# Imprimir los valores de las intersecciones
print("Intersección A ∩ B:", intersection_AB)
print("Intersección A ∩ C:", intersection_AC)
print("Intersección B ∩ C:", intersection_BC)
print("Intersección A ∩ B ∩ C:", intersection_ABC)

# Crear el diagrama de Venn
venn = venn3(
    subsets=(len(A - B - C), len(B - A - C), len(A & B - C), 
             len(C - A - B), len(A & C - B), len(B & C - A), len(A & B & C)),
    set_labels=("Bacillus", "Lactobacillus", "Propionibacterium")
)

# Personalizar el estilo
for subset in venn.subset_labels:
    if subset:  # Evitar etiquetas vacías
        subset.set_fontsize(10)

plt.title("Pathways")
plt.show()
# Out:
# Intersección A ∩ B: {'NAD+', 'Pertussis', 'Cytokine Signaling In Immune System', 'Chemokine Receptors Bind Chemokines', 'Legionellosis', 'IL1B Expression Targets -> Nociception', 'Interleukin-10 Signaling', 'Rheumatoid arthritis', 'Retinoic Acid'}
# Intersección A ∩ C: set()
# Intersección B ∩ C: {'Retinol metabolism'}
# Intersección A ∩ B ∩ C: set()
