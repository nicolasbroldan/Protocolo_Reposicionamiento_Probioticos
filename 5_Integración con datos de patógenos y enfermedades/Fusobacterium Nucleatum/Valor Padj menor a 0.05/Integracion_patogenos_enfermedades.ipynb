# %%
import pandas as pd

# %%
# Leer los archivos y crear los DataFrames
DisGeNET_df = pd.read_csv('DisGeNET_table.txt', delimiter='\t')
GeDiPNet_df = pd.read_csv('GeDiPNet_2023_table.txt', delimiter='\t')
Orphanet_df = pd.read_csv('Orphanet_Augmented_2021_table.txt', delimiter='\t')
Virus_Host_df = pd.read_csv('Virus-Host_PPI_P-HIPSTer_2020_table.txt', delimiter='\t')


# Renombrar la columna 'Term' para cada DataFrame
DisGeNET_df = DisGeNET_df.rename(columns={'Term': 'DisGeNET_Term'})
GeDiPNet_df = GeDiPNet_df.rename(columns={'Term': 'GeDiPNet_Term'})
Orphanet_df = Orphanet_df.rename(columns={'Term': 'Orphanet_Term'})
Virus_Host_df = Virus_Host_df.rename(columns={'Term': 'Virus_Host_Term'})

# %%
DisGeNET_df
# Out:
#                      DisGeNET_Term  Overlap   P-value  Adjusted P-value  \
# 0             Colorectal Carcinoma  59/2931  0.000002          0.003460
# 1                Mammary Neoplasms  51/2387  0.000003          0.003460
# 2                Ovarian Carcinoma  48/2203  0.000003          0.003460
# 3                 Breast Carcinoma  85/4963  0.000006          0.004255
# 4     Invasive carcinoma of breast   15/385  0.000028          0.014900
# ...                            ...      ...       ...               ...
# 3077   Charcot-Marie-Tooth Disease    1/298  0.964962          0.966216
# 3078                Virus Diseases    5/875  0.968273          0.969217
# 3079                Blepharoptosis    1/337  0.977487          0.978122
# 3080      Genetic Diseases, Inborn    2/507  0.977840          0.978157
# 3081                    Strabismus    1/404  0.989492          0.989492
#
#       Old P-value  Old Adjusted P-value  Odds Ratio  Combined Score  \
# 0               0                     0    2.130693       27.546915
# 1               0                     0    2.226884       28.551846
# 2               0                     0    2.255924       28.427189
# 3               0                     0    1.895147       22.944168
# 4               0                     0    3.801018       39.831893
# ...           ...                   ...         ...             ...
# 3077            0                     0    0.296799        0.010586
# 3078            0                     0    0.500768        0.016145
# 3079            0                     0    0.261824        0.005962
# 3080            0                     0    0.346949        0.007775
# 3081            0                     0    0.217543        0.002298
#
#                                                   Genes
# 0     COL12A1;SETD7;ICA1;KRT23;BBC3;CASP7;CCND1;SLC2...
# 1     SETD7;GLI2;CASP7;CCND1;HYAL1;SLC22A18;LAMP3;EN...
# 2     OGFR;EHF;ABCB1;LAMA3;NOLC1;IQGAP2;CORO1A;FHIT;...
# 3     CNTNAP1;COL12A1;SETD7;RTKN2;PRSS23;BBC3;GLI2;D...
# 4     FZD1;ABCB1;SORBS1;FHIT;THBS1;KAT2B;KITLG;CHST1...
# ...                                                 ...
# 3077                                              SORT1
# 3078                      ABCC2;LAMP3;CORO1A;THBS1;TGM2
# 3079                                             B3GLCT
# 3080                                        ZBTB18;GLI2
# 3081                                              DMBX1
#
# [3082 rows x 9 columns]

# %%
GeDiPNet_df
# Out:
#                                         GeDiPNet_Term Overlap   P-value  \
# 0                          Anomalous Pulmonary Artery    4/14  0.000014
# 1    Congenital Anomalies Of Kidney And Urinary Tract    4/16  0.000024
# 2                                    Breast Carcinoma  24/859  0.000032
# 3                                  Esophagus Neoplasm  11/234  0.000064
# 4                                Urinary Tract Cancer     3/8  0.000073
# ..                                                ...     ...       ...
# 703                                 Diabetes Mellitus  7/1096  0.962920
# 704                                        Dysarthria   2/470  0.968320
# 705                          Developmental Regression   1/326  0.974493
# 706                                            Autism   3/650  0.976951
# 707                     Hypoplasia Of Corpus Callosum   1/351  0.980796
#
#      Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0            0.007586            0                     0   36.271560
# 1            0.007586            0                     0   30.223242
# 2            0.007586            0                     0    2.749846
# 3            0.010268            0                     0    4.571547
# 4            0.010268            0                     0   54.172603
# ..                ...          ...                   ...         ...
# 703          0.968391            0                     0    0.558750
# 704          0.972440            0                     0    0.375097
# 705          0.977254            0                     0    0.270839
# 706          0.978333            0                     0    0.405052
# 707          0.980796            0                     0    0.251170
#
#      Combined Score                                              Genes
# 0        406.563842                             KITLG;B3GLCT;SNAI2;ENG
# 1        321.227849                               SIX2;NRIP1;LIFR;PBX1
# 2         28.447886  H2AX;PLEKHD1;GRAMD1B;CNTNAP1;ABCB1;RTKN2;THBS1...
# 3         44.121489  ZCCHC12;ABCB1;ABCC2;CCND1;TPM4;CA2;KRT13;SNAI2...
# 4        516.358795                                 SULT1A1;CCND1;FHIT
# ..              ...                                                ...
# 703        0.021112     RPSAP52;ARL2BP;MIR17HG;SORBS1;EFR3B;MICB;PSMB9
# 704        0.012075                                        NR4A2;PDGFB
# 705        0.006998                                              SUMF1
# 706        0.009445                                NR4A2;CNTNAP2;PDE4B
# 707        0.004870                                            CNTNAP1
#
# [708 rows x 9 columns]

# %%
Orphanet_df
# Out:
#                                           Orphanet_Term Overlap   P-value  \
# 0     Atrial septal defect, ostium primum type ORPHA...   9/101  0.000002
# 1        Arnold-Chiari malformation type I ORPHA:268882   8/101  0.000017
# 2       Autosomal recessive nail dysplasia ORPHA:280654   8/101  0.000017
# 3     Hereditary arterial and articular multiple cal...   8/101  0.000017
# 4     Interstitial lung disease-nephrotic syndrome-e...   8/101  0.000017
# ...                                                 ...     ...       ...
# 2147  Genetic steroid-resistant nephrotic syndrome O...   1/129  0.764149
# 2148  X-linked non-syndromic intellectual disability...   1/132  0.771966
# 2149            Amyotrophic lateral sclerosis ORPHA:803   1/137  0.784426
# 2150  Autosomal recessive non-syndromic intellectual...   1/140  0.791574
# 2151                     Retinitis pigmentosa ORPHA:791   1/174  0.857824
#
#       Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0             0.004036            0                     0    9.041335
# 1             0.005185            0                     0    7.912773
# 2             0.005185            0                     0    7.912773
# 3             0.005185            0                     0    7.912773
# 4             0.005185            0                     0    7.912773
# ...                ...          ...                   ...         ...
# 2147          0.765572            0                     0    0.694641
# 2148          0.773044            0                     0    0.678629
# 2149          0.785156            0                     0    0.653513
# 2150          0.791942            0                     0    0.639311
# 2151          0.857824            0                     0    0.512777
#
#       Combined Score                                              Genes
# 0         119.224633  KITLG;PCDH7;COL12A1;COL5A2;PLSCR4;LAMA3;SNAI2;...
# 1          86.933465  RPSAP52;KITLG;CCND1;PLK2;ITGA2;COL12A1;SNAI2;A...
# 2          86.933465  KITLG;CCND1;PLK2;ITGA2;COL12A1;LAMA3;SNAI2;AMOTL2
# 3          86.933465  ITGA2;COL12A1;PLSCR4;SNAI2;PRSS23;THBS1;TGM2;MT1E
# 4          86.933465  CCND1;PLK2;ITGA2;COL12A1;LAMA3;AMOTL2;PRSS23;CPA4
# ...              ...                                                ...
# 2147        0.186853                                              CENPE
# 2148        0.175639                                            ZCCHC12
# 2149        0.158675                                              GANAB
# 2150        0.149428                                              GANAB
# 2151        0.078638                                             ARL2BP
#
# [2152 rows x 9 columns]

# %%
Virus_Host_df
# Out:
#                                         Virus_Host_Term Overlap   P-value  \
# 0     Norovirus Hu/Norwalk/10074/2009/VNM capsid pro...    3/51  0.019008
# 1     Norovirus Hu/Norwalk/20047/2009/VNM capsid pro...    3/51  0.019008
# 2       Norovirus Hu/GII-4/CBNU2/2007/KR capsid protein    3/52  0.020011
# 3     Norovirus Hu/Norwalk/10247/2009/VNM capsid pro...    3/52  0.020011
# 4     Lujo mammarenavirus multifunctional matrix-lik...    2/20  0.020434
# ...                                                 ...     ...       ...
# 1529  Macacine alphaherpesvirus 1 serine/threonine p...   4/833  0.984215
# 1530  Human betaherpesvirus 6B glycoprotein (gene: U85)   1/383  0.986653
# 1531  Papiine alphaherpesvirus 2 serine/threonine pr...   4/855  0.986862
# 1532  Human alphaherpesvirus 3 serine/threonine prot...   4/868  0.988222
# 1533  Human alphaherpesvirus 1 serine/threonine prot...   4/872  0.988613
#
#       Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0             0.636278            0                     0    5.630708
# 1             0.636278            0                     0    5.630708
# 2             0.636278            0                     0    5.515516
# 3             0.636278            0                     0    5.515516
# 4             0.636278            0                     0    9.979798
# ...                ...          ...                   ...         ...
# 1529          0.986788            0                     0    0.419407
# 1530          0.988150            0                     0    0.229751
# 1531          0.988150            0                     0    0.408090
# 1532          0.988613            0                     0    0.401673
# 1533          0.988613            0                     0    0.399738
#
#       Combined Score                   Genes
# 0          22.313857       TRIB3;THBS1;PSMB9
# 1          22.313857       TRIB3;THBS1;PSMB9
# 2          21.573922       TRIB3;THBS1;PSMB9
# 3          21.573922       TRIB3;THBS1;PSMB9
# 4          38.826986             TRIB3;SMAD7
# ...              ...                     ...
# 1529        0.006673  CCND1;PLK2;MKNK2;TRIB3
# 1530        0.003087                CEACAM19
# 1531        0.005397  CCND1;PLK2;MKNK2;TRIB3
# 1532        0.004759  CCND1;PLK2;MKNK2;TRIB3
# 1533        0.004578  CCND1;PLK2;MKNK2;TRIB3
#
# [1534 rows x 9 columns]

# %%
# Verificar los tipos de datos de las columnas
print(Virus_Host_df['Genes'].apply(type).value_counts())
# Out:
# Genes
# <class 'str'>    1534
# Name: count, dtype: int64

# %%
# Filtrar cada DataFrame por 'Adjusted P-value' < 0.05
DisGeNET = DisGeNET_df[DisGeNET_df['Adjusted P-value'] < 0.05]
GeDiPNet = GeDiPNet_df[GeDiPNet_df['Adjusted P-value'] < 0.05]
Orphanet = Orphanet_df[Orphanet_df['Adjusted P-value'] < 0.05]
Virus_Host = Virus_Host_df[Virus_Host_df['Adjusted P-value'] < 0.05]

# %%
# Leer el archivo TSV
Intact_df = pd.read_csv('Interactions_intact_Fusobacterium_Nucleatum.txt', delimiter='\t')
# Mostrar el DataFrame
Intact_df
# Out:
#                   # ID(s) interactor A               ID(s) interactor B  \
# 0      uniprotkb:Q99523-PRO_0000033163  uniprotkb:Q99523-PRO_0000033162
# 1                  chebi:"CHEBI:91149"  uniprotkb:Q9Y251-PRO_0000042262
# 2                  chebi:"CHEBI:91149"  uniprotkb:Q9Y251-PRO_0000042260
# 3                  chebi:"CHEBI:91148"  uniprotkb:Q9Y251-PRO_0000042262
# 4                  chebi:"CHEBI:91148"  uniprotkb:Q9Y251-PRO_0000042260
# ...                                ...                              ...
# 16262               uniprotkb:Q9UQR0-1                 uniprotkb:P24941
# 16263                 uniprotkb:P24941               uniprotkb:Q9UQR0-1
# 16264                 uniprotkb:O95084                 uniprotkb:P61769
# 16265                 uniprotkb:P0DTC2                 uniprotkb:P67936
# 16266                 uniprotkb:P0DTC2                 uniprotkb:O43264
#
#                                  Alt. ID(s) interactor A  \
# 0      uniprotkb:Q99523-PRO_0000033163|intact:EBI-214...
# 1                                    intact:EBI-11663946
# 2                                    intact:EBI-11663946
# 3                                    intact:EBI-11664424
# 4                                    intact:EBI-11664424
# ...                                                  ...
# 16262  ensembl:ENSP00000251900.4|intact:EBI-16087037|...
# 16263  uniprotkb:A8K7C6|uniprotkb:O75100|ensembl:ENSP...
# 16264  uniprotkb:B2RDJ1|uniprotkb:B4E2J3|uniprotkb:Q6...
# 16265               intact:EBI-25474821|uniprotkb:P0DTC2
# 16266               intact:EBI-25474821|uniprotkb:P0DTC2
#
#                                  Alt. ID(s) interactor B  \
# 0      uniprotkb:Q99523-PRO_0000033162|intact:EBI-214...
# 1      uniprotkb:Q9Y251-PRO_0000042262|intact:EBI-116...
# 2      uniprotkb:Q9Y251-PRO_0000042260|intact:EBI-116...
# 3      uniprotkb:Q9Y251-PRO_0000042262|intact:EBI-116...
# 4      uniprotkb:Q9Y251-PRO_0000042260|intact:EBI-116...
# ...                                                  ...
# 16262  uniprotkb:A8K7C6|uniprotkb:O75100|ensembl:ENSP...
# 16263  ensembl:ENSP00000251900.4|intact:EBI-16087037|...
# 16264  uniprotkb:P01884|uniprotkb:Q9UDF4|uniprotkb:Q5...
# 16265  uniprotkb:P07226|uniprotkb:Q15659|uniprotkb:Q9...
# 16266  uniprotkb:A1A528|ensembl:ENSP00000200135.3|int...
#
#                                   Alias(es) interactor A  \
# 0      psi-mi:q99523-pro_0000033163(display_short)|ps...
# 1      psi-mi:"beta-d-deltahexa(2s)-(1->4)-alpha-d-gl...
# 2      psi-mi:"beta-d-deltahexa(2s)-(1->4)-alpha-d-gl...
# 3      psi-mi:heparin nonasaccharide(display_short)|p...
# 4      psi-mi:heparin nonasaccharide(display_short)|p...
# ...                                                  ...
# 16262  psi-mi:q9uqr0-1(display_short)|psi-mi:Sex comb...
# 16263  psi-mi:cdk2_human(display_short)|psi-mi:Cyclin...
# 16264  psi-mi:prs23_human(display_short)|psi-mi:Serin...
# 16265  psi-mi:spike_sars2(display_short)|psi-mi:Spike...
# 16266  psi-mi:spike_sars2(display_short)|psi-mi:Spike...
#
#                                   Alias(es) interactor B  \
# 0      psi-mi:q99523-pro_0000033162(display_short)|ps...
# 1      psi-mi:q9y251-pro_0000042262(display_short)|ps...
# 2      psi-mi:q9y251-pro_0000042260(display_short)|ps...
# 3      psi-mi:q9y251-pro_0000042262(display_short)|ps...
# 4      psi-mi:q9y251-pro_0000042260(display_short)|ps...
# ...                                                  ...
# 16262  psi-mi:cdk2_human(display_short)|psi-mi:Cyclin...
# 16263  psi-mi:q9uqr0-1(display_short)|psi-mi:Sex comb...
# 16264  psi-mi:b2mg_human(display_short)|psi-mi:Beta-2...
# 16265  psi-mi:tpm4_human(display_short)|psi-mi:Tropom...
# 16266  psi-mi:zw10_human(display_short)|psi-mi:Centro...
#
#                         Interaction detection method(s)  \
# 0           psi-mi:"MI:0107"(surface plasmon resonance)
# 1               psi-mi:"MI:0114"(x-ray crystallography)
# 2               psi-mi:"MI:0114"(x-ray crystallography)
# 3               psi-mi:"MI:0114"(x-ray crystallography)
# 4               psi-mi:"MI:0114"(x-ray crystallography)
# ...                                                 ...
# 16262                       psi-mi:"MI:0096"(pull down)
# 16263               psi-mi:"MI:0071"(molecular sieving)
# 16264     psi-mi:"MI:0398"(two hybrid pooling approach)
# 16265  psi-mi:"MI:0007"(anti tag coimmunoprecipitation)
# 16266                       psi-mi:"MI:0096"(pull down)
#
#        Publication 1st author(s)  \
# 0      Gustafsen C. et al.(2013)
# 1             Wu L. et al.(2015)
# 2             Wu L. et al.(2015)
# 3             Wu L. et al.(2015)
# 4             Wu L. et al.(2015)
# ...                          ...
# 16262     Lecona E. et al.(2013)
# 16263     Lecona E. et al.(2013)
# 16264     Stelzl U. et al.(2005)
# 16265       Zhou Y. et al.(2022)
# 16266    Gutmann C. et al.(2021)
#
#                                Publication Identifier(s)  \
# 0      intact:EBI-21183089|pubmed:23283322|imex:IM-27151
# 1      intact:EBI-11508739|pubmed:26575439|imex:IM-24973
# 2      intact:EBI-11508739|pubmed:26575439|imex:IM-24973
# 3      intact:EBI-11508739|pubmed:26575439|imex:IM-24973
# 4      intact:EBI-11508739|pubmed:26575439|imex:IM-24973
# ...                                                  ...
# 16262  intact:EBI-16086972|doi:10.1371/journal.pbio.1...
# 16263  intact:EBI-16086972|doi:10.1371/journal.pbio.1...
# 16264  intact:EBI-1991041|pubmed:16169070|mint:MINT-5...
# 16265  intact:EBI-36481508|doi:10.1038/s41587-022-014...
# 16266  intact:EBI-26989108|pubmed:34099652|imex:IM-29052
#
#                                       Taxid interactor A  ...  \
# 0             taxid:9606(human)|taxid:9606(Homo sapiens)  ...
# 1      taxid:-2(chemical synthesis)|taxid:-2("Chemica...  ...
# 2      taxid:-2(chemical synthesis)|taxid:-2("Chemica...  ...
# 3      taxid:-2(chemical synthesis)|taxid:-2("Chemica...  ...
# 4      taxid:-2(chemical synthesis)|taxid:-2("Chemica...  ...
# ...                                                  ...  ...
# 16262         taxid:9606(human)|taxid:9606(Homo sapiens)  ...
# 16263         taxid:9606(human)|taxid:9606(Homo sapiens)  ...
# 16264         taxid:9606(human)|taxid:9606(Homo sapiens)  ...
# 16265  taxid:2697049(SARS-CoV-2)|taxid:2697049(SARS-C...  ...
# 16266  taxid:2697049(SARS-CoV-2)|taxid:2697049(SARS-C...  ...
#
#       Checksum(s) interactor A Checksum(s) interactor B  \
# 0       crc64:D84A44B881C93DFE   crc64:8B4FBA7D1F064300
# 1                            -   crc64:3C6EF773788CB1F7
# 2                            -   crc64:CCD163EC9D4705B2
# 3                            -   crc64:3C6EF773788CB1F7
# 4                            -   crc64:CCD163EC9D4705B2
# ...                        ...                      ...
# 16262                        -   crc64:F90A0F4E70910B51
# 16263   crc64:F90A0F4E70910B51                        -
# 16264   crc64:46EB6C11ABFD5E8F   crc64:AFD2DBEF07DCEF27
# 16265                        -   crc64:5D5CDF6BF76552A8
# 16266                        -   crc64:9C38186153886481
#
#       Interaction Checksum(s) Negative  \
# 0                           -        -
# 1                           -        -
# 2                           -        -
# 3                           -        -
# 4                           -        -
# ...                       ...      ...
# 16262                       -        -
# 16263                       -        -
# 16264                       -        -
# 16265                       -        -
# 16266                       -        -
#
#                                  Feature(s) interactor A  \
# 0                                            his tag:c-c
# 1                                                      -
# 2                                                      -
# 3                                                      -
# 4                                                      -
# ...                                                  ...
# 16262  one-strep-tag:n-n|sufficient binding region:1-609
# 16263                                                  -
# 16264                                                  -
# 16265                                       flag tag:c-c
# 16266      his tag:c-c|sufficient binding region:11-1208
#
#                 Feature(s) interactor B Stoichiometry(s) interactor A  \
# 0      glutathione s tranferase tag:n-n                             0
# 1       sufficient binding region:2-386                             0
# 2                                     -                             0
# 3       sufficient binding region:2-386                             0
# 4                                     -                             0
# ...                                 ...                           ...
# 16262                                 -                             0
# 16263   sufficient binding region:1-609                             0
# 16264                                 -                             0
# 16265                                 -                             0
# 16266                                 -                             0
#
#       Stoichiometry(s) interactor B  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 16262                             0
# 16263                             0
# 16264                             0
# 16265                             0
# 16266                             0
#
#                      Identification method participant A  \
# 0            psi-mi:"MI:0396"(predetermined participant)
# 1            psi-mi:"MI:0396"(predetermined participant)
# 2            psi-mi:"MI:0396"(predetermined participant)
# 3            psi-mi:"MI:0396"(predetermined participant)
# 4            psi-mi:"MI:0396"(predetermined participant)
# ...                                                  ...
# 16262                     psi-mi:"MI:0113"(western blot)
# 16263        psi-mi:"MI:0396"(predetermined participant)
# 16264  psi-mi:"MI:0078"(nucleotide sequence identific...
# 16265      psi-mi:"MI:0102"(sequence tag identification)
# 16266      psi-mi:"MI:0102"(sequence tag identification)
#
#                      Identification method participant B
# 0            psi-mi:"MI:0396"(predetermined participant)
# 1            psi-mi:"MI:0396"(predetermined participant)
# 2            psi-mi:"MI:0396"(predetermined participant)
# 3            psi-mi:"MI:0396"(predetermined participant)
# 4            psi-mi:"MI:0396"(predetermined participant)
# ...                                                  ...
# 16262                     psi-mi:"MI:0113"(western blot)
# 16263        psi-mi:"MI:0396"(predetermined participant)
# 16264  psi-mi:"MI:0078"(nucleotide sequence identific...
# 16265      psi-mi:"MI:0102"(sequence tag identification)
# 16266      psi-mi:"MI:0102"(sequence tag identification)
#
# [16267 rows x 42 columns]

# %%
# Verificar datos y limpiar si es necesario
DisGeNET_df['Genes'] = DisGeNET_df['Genes'].str.split(';')
GeDiPNet_df['Genes'] = GeDiPNet_df['Genes'].str.split(';')
Orphanet_df['Genes'] = Orphanet_df['Genes'].str.split(';')
Virus_Host_df['Genes'] = Virus_Host_df['Genes'].str.split(';')
Intact_df['Alias(es) interactor A'] = Intact_df['Alias(es) interactor A'].str.split('|')
Intact_df['Alias(es) interactor B'] = Intact_df['Alias(es) interactor B'].str.split('|')

# %%
# Extraer listas de genes
disgenet_genes = set([gene for sublist in DisGeNET_df['Genes'] for gene in sublist])
gedipnet_genes = set([gene for sublist in GeDiPNet_df['Genes'] for gene in sublist])
orphanet_genes = set([gene for sublist in Orphanet_df['Genes'] for gene in sublist])
virus_host_genes = set([gene for sublist in Virus_Host_df['Genes'] for gene in sublist])

# Genes en común
common_genes = disgenet_genes.intersection(gedipnet_genes, orphanet_genes, virus_host_genes)

print(f"Genes comunes entre todas las bases de datos: {common_genes}")
# Out:
# Genes comunes entre todas las bases de datos: {'SMAD6', 'PDGFB', 'SMAD7', 'ISL1', 'THBS1', 'NR4A2', 'ZBTB18', 'EHF', 'HSDL2', 'KAT2B', 'DMBX1', 'COL12A1', 'CA2', 'GANAB', 'SKAP1', 'SORL1', 'BBC3', 'LRIG1', 'RHOU', 'PLK2', 'PBX1', 'CPEB4', 'TRIB3', 'ACTA2', 'NCEH1', 'GABRQ', 'SORBS1', 'TPM4', 'NGFR', 'ABCC2', 'CASP7', 'KBTBD8', 'CCND1', 'MICB', 'GLI2', 'ITGA2', 'PSMB9', 'SIX2', 'CTSD', 'SCML2', 'ABCB1', 'LIFR'}

# %%
import re

# Función para extraer nombres de genes de un alias
def extract_gene_names(alias_list):
    gene_names = []
    if isinstance(alias_list, list):  # Asegurarse de que alias_list es una lista
        for alias in alias_list:
            # Buscar un nombre de gen que siga el patrón 'uniprotkb:GENE_NAME(gene name)'
            match = re.search(r'uniprotkb:([\w-]+)\(gene name\)', alias)
            if match:
                gene_names.append(match.group(1))
    return ','.join(gene_names)  # Convertir la lista de nombres a una cadena separada por comas

# Asegurarse de que las columnas de alias están en el formato adecuado
Intact_df['Alias(es) interactor A'] = Intact_df['Alias(es) interactor A'].apply(lambda x: eval(x) if isinstance(x, str) else x)
Intact_df['Alias(es) interactor B'] = Intact_df['Alias(es) interactor B'].apply(lambda x: eval(x) if isinstance(x, str) else x)

# Aplicar la función a las columnas de alias
Intact_df['Interactor A Genes'] = Intact_df['Alias(es) interactor A'].apply(extract_gene_names)
Intact_df['Interactor B Genes'] = Intact_df['Alias(es) interactor B'].apply(extract_gene_names)

# Verifica el resultado
print(Intact_df[['Interactor A Genes', 'Interactor B Genes']].head())
# Out:
#   Interactor A Genes Interactor B Genes
# 0              SORT1              SORT1
# 1                                  HPSE
# 2                                  HPSE
# 3                                  HPSE
# 4                                  HPSE

# %%
Intact_df.head()
# Out:
#               # ID(s) interactor A               ID(s) interactor B  \
# 0  uniprotkb:Q99523-PRO_0000033163  uniprotkb:Q99523-PRO_0000033162
# 1              chebi:"CHEBI:91149"  uniprotkb:Q9Y251-PRO_0000042262
# 2              chebi:"CHEBI:91149"  uniprotkb:Q9Y251-PRO_0000042260
# 3              chebi:"CHEBI:91148"  uniprotkb:Q9Y251-PRO_0000042262
# 4              chebi:"CHEBI:91148"  uniprotkb:Q9Y251-PRO_0000042260
#
#                              Alt. ID(s) interactor A  \
# 0  uniprotkb:Q99523-PRO_0000033163|intact:EBI-214...
# 1                                intact:EBI-11663946
# 2                                intact:EBI-11663946
# 3                                intact:EBI-11664424
# 4                                intact:EBI-11664424
#
#                              Alt. ID(s) interactor B  \
# 0  uniprotkb:Q99523-PRO_0000033162|intact:EBI-214...
# 1  uniprotkb:Q9Y251-PRO_0000042262|intact:EBI-116...
# 2  uniprotkb:Q9Y251-PRO_0000042260|intact:EBI-116...
# 3  uniprotkb:Q9Y251-PRO_0000042262|intact:EBI-116...
# 4  uniprotkb:Q9Y251-PRO_0000042260|intact:EBI-116...
#
#                               Alias(es) interactor A  \
# 0  [psi-mi:q99523-pro_0000033163(display_short), ...
# 1  [psi-mi:"beta-d-deltahexa(2s)-(1->4)-alpha-d-g...
# 2  [psi-mi:"beta-d-deltahexa(2s)-(1->4)-alpha-d-g...
# 3  [psi-mi:heparin nonasaccharide(display_short),...
# 4  [psi-mi:heparin nonasaccharide(display_short),...
#
#                               Alias(es) interactor B  \
# 0  [psi-mi:q99523-pro_0000033162(display_short), ...
# 1  [psi-mi:q9y251-pro_0000042262(display_short), ...
# 2  [psi-mi:q9y251-pro_0000042260(display_short), ...
# 3  [psi-mi:q9y251-pro_0000042262(display_short), ...
# 4  [psi-mi:q9y251-pro_0000042260(display_short), ...
#
#                Interaction detection method(s)  Publication 1st author(s)  \
# 0  psi-mi:"MI:0107"(surface plasmon resonance)  Gustafsen C. et al.(2013)
# 1      psi-mi:"MI:0114"(x-ray crystallography)         Wu L. et al.(2015)
# 2      psi-mi:"MI:0114"(x-ray crystallography)         Wu L. et al.(2015)
# 3      psi-mi:"MI:0114"(x-ray crystallography)         Wu L. et al.(2015)
# 4      psi-mi:"MI:0114"(x-ray crystallography)         Wu L. et al.(2015)
#
#                            Publication Identifier(s)  \
# 0  intact:EBI-21183089|pubmed:23283322|imex:IM-27151
# 1  intact:EBI-11508739|pubmed:26575439|imex:IM-24973
# 2  intact:EBI-11508739|pubmed:26575439|imex:IM-24973
# 3  intact:EBI-11508739|pubmed:26575439|imex:IM-24973
# 4  intact:EBI-11508739|pubmed:26575439|imex:IM-24973
#
#                                   Taxid interactor A  ...  \
# 0         taxid:9606(human)|taxid:9606(Homo sapiens)  ...
# 1  taxid:-2(chemical synthesis)|taxid:-2("Chemica...  ...
# 2  taxid:-2(chemical synthesis)|taxid:-2("Chemica...  ...
# 3  taxid:-2(chemical synthesis)|taxid:-2("Chemica...  ...
# 4  taxid:-2(chemical synthesis)|taxid:-2("Chemica...  ...
#
#   Interaction Checksum(s) Negative Feature(s) interactor A  \
# 0                       -        -             his tag:c-c
# 1                       -        -                       -
# 2                       -        -                       -
# 3                       -        -                       -
# 4                       -        -                       -
#
#             Feature(s) interactor B Stoichiometry(s) interactor A  \
# 0  glutathione s tranferase tag:n-n                             0
# 1   sufficient binding region:2-386                             0
# 2                                 -                             0
# 3   sufficient binding region:2-386                             0
# 4                                 -                             0
#
#   Stoichiometry(s) interactor B          Identification method participant A  \
# 0                             0  psi-mi:"MI:0396"(predetermined participant)
# 1                             0  psi-mi:"MI:0396"(predetermined participant)
# 2                             0  psi-mi:"MI:0396"(predetermined participant)
# 3                             0  psi-mi:"MI:0396"(predetermined participant)
# 4                             0  psi-mi:"MI:0396"(predetermined participant)
#
#            Identification method participant B Interactor A Genes  \
# 0  psi-mi:"MI:0396"(predetermined participant)              SORT1
# 1  psi-mi:"MI:0396"(predetermined participant)
# 2  psi-mi:"MI:0396"(predetermined participant)
# 3  psi-mi:"MI:0396"(predetermined participant)
# 4  psi-mi:"MI:0396"(predetermined participant)
#
#   Interactor B Genes
# 0              SORT1
# 1               HPSE
# 2               HPSE
# 3               HPSE
# 4               HPSE
#
# [5 rows x 44 columns]

# %%
Intact_df.columns
# Out:
# Index(['# ID(s) interactor A', 'ID(s) interactor B', 'Alt. ID(s) interactor A',
#        'Alt. ID(s) interactor B', 'Alias(es) interactor A',
#        'Alias(es) interactor B', 'Interaction detection method(s)',
#        'Publication 1st author(s)', 'Publication Identifier(s)',
#        'Taxid interactor A', 'Taxid interactor B', 'Interaction type(s)',
#        'Source database(s)', 'Interaction identifier(s)',
#        'Confidence value(s)', 'Expansion method(s)',
#        'Biological role(s) interactor A', 'Biological role(s) interactor B',
#        'Experimental role(s) interactor A',
#        'Experimental role(s) interactor B', 'Type(s) interactor A',
#        'Type(s) interactor B', 'Xref(s) interactor A', 'Xref(s) interactor B',
#        'Interaction Xref(s)', 'Annotation(s) interactor A',
#        'Annotation(s) interactor B', 'Interaction annotation(s)',
#        'Host organism(s)', 'Interaction parameter(s)', 'Creation date',
#        'Update date', 'Checksum(s) interactor A', 'Checksum(s) interactor B',
#        'Interaction Checksum(s)', 'Negative', 'Feature(s) interactor A',
#        'Feature(s) interactor B', 'Stoichiometry(s) interactor A',
#        'Stoichiometry(s) interactor B', 'Identification method participant A',
#        'Identification method participant B', 'Interactor A Genes',
#        'Interactor B Genes'],
#       dtype='object')

# %%
# Seleccionar solo las columnas de interés
columnas_interes = ['Interactor A Genes', 'Interactor B Genes', 'Host organism(s)', 'Confidence value(s)', 'Taxid interactor A', 'Taxid interactor B']
Intact_df_reducido = Intact_df[columnas_interes]

# Mostrar las primeras filas del nuevo DataFrame para verificar
Intact_df_reducido.head()
# Out:
#   Interactor A Genes Interactor B Genes  \
# 0              SORT1              SORT1
# 1                                  HPSE
# 2                                  HPSE
# 3                                  HPSE
# 4                                  HPSE
#
#                         Host organism(s)  Confidence value(s)  \
# 0  taxid:-1(in vitro)|taxid:-1(In vitro)   intact-miscore:0.4
# 1  taxid:-1(in vitro)|taxid:-1(In vitro)  intact-miscore:0.44
# 2  taxid:-1(in vitro)|taxid:-1(In vitro)  intact-miscore:0.44
# 3  taxid:-1(in vitro)|taxid:-1(In vitro)  intact-miscore:0.44
# 4  taxid:-1(in vitro)|taxid:-1(In vitro)  intact-miscore:0.44
#
#                                   Taxid interactor A  \
# 0         taxid:9606(human)|taxid:9606(Homo sapiens)
# 1  taxid:-2(chemical synthesis)|taxid:-2("Chemica...
# 2  taxid:-2(chemical synthesis)|taxid:-2("Chemica...
# 3  taxid:-2(chemical synthesis)|taxid:-2("Chemica...
# 4  taxid:-2(chemical synthesis)|taxid:-2("Chemica...
#
#                            Taxid interactor B
# 0  taxid:9606(human)|taxid:9606(Homo sapiens)
# 1  taxid:9606(human)|taxid:9606(Homo sapiens)
# 2  taxid:9606(human)|taxid:9606(Homo sapiens)
# 3  taxid:9606(human)|taxid:9606(Homo sapiens)
# 4  taxid:9606(human)|taxid:9606(Homo sapiens)

# %%
# Limpiar la columna 'Confidence value(s)' para extraer solo el valor numérico
Intact_df_reducido['Confidence value(s)'] = Intact_df_reducido['Confidence value(s)'].str.extract(r'(\d+\.\d+)', expand=False)

# Limpiar las columnas 'Taxid interactor A' y 'Taxid interactor B' para extraer el contenido del último paréntesis
def extract_last_taxid(text):
    # Extraer el contenido después de 'taxid:652616' si está presente
    if "taxid:652616" in text:
        # Buscar la secuencia taxid:652616 y extraer el contenido entre los paréntesis
        match = re.search(r'taxid:652616\("([^"]+)"\)', text)
        if match:
            return match.group(1)
    
    # Si no se encuentra taxid:652616, realizar la limpieza habitual
    # Primera limpieza para eliminar comillas y paréntesis incompletos
    cleaned_text = re.sub(r'\s*".*$', '', text)
    # Encontrar el último paréntesis válido
    matches = re.findall(r'taxid:[\d-]+\(([^)]+)\)', cleaned_text)
    return matches[-1] if matches else text

Intact_df_reducido['Taxid interactor A'] = Intact_df_reducido['Taxid interactor A'].apply(extract_last_taxid)
Intact_df_reducido['Taxid interactor B'] = Intact_df_reducido['Taxid interactor B'].apply(extract_last_taxid)
# Limpiar la columna 'Host organism(s)' para extraer solo el contenido del último paréntesis
Intact_df_reducido['Host organism(s)'] = Intact_df_reducido['Host organism(s)'].apply(extract_last_taxid)

# Mostrar las primeras filas del DataFrame para verificar
Intact_df_reducido.head()
# Out:
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\128504076.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Intact_df_reducido['Confidence value(s)'] = Intact_df_reducido['Confidence value(s)'].str.extract(r'(\d+\.\d+)', expand=False)
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\128504076.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Intact_df_reducido['Taxid interactor A'] = Intact_df_reducido['Taxid interactor A'].apply(extract_last_taxid)
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\128504076.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Intact_df_reducido['Taxid interactor B'] = Intact_df_reducido['Taxid interactor B'].apply(extract_last_taxid)
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\128504076.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Intact_df_reducido['Host organism(s)'] = Intact_df_reducido['Host organism(s)'].apply(extract_last_taxid)
#   Interactor A Genes Interactor B Genes Host organism(s) Confidence value(s)  \
# 0              SORT1              SORT1         In vitro                 0.4
# 1                                  HPSE         In vitro                0.44
# 2                                  HPSE         In vitro                0.44
# 3                                  HPSE         In vitro                0.44
# 4                                  HPSE         In vitro                0.44
#
#    Taxid interactor A Taxid interactor B
# 0        Homo sapiens       Homo sapiens
# 1  chemical synthesis       Homo sapiens
# 2  chemical synthesis       Homo sapiens
# 3  chemical synthesis       Homo sapiens
# 4  chemical synthesis       Homo sapiens

# %%
# Función para expandir listas de genes en filas individuales
def expand_genes(df, gene_column):
    df_expanded = df.copy()
    # Convertir la columna 'gene_column' en listas de genes
    df_expanded[gene_column] = df_expanded[gene_column].apply(
        lambda x: [gene.strip() for gene in x.split(';')] if isinstance(x, str) else [x]
    )
    # Expandir las listas en filas individuales
    df_expanded = df_expanded.explode(gene_column).reset_index(drop=True)
    return df_expanded

# %%
# Leer los archivos y crear los DataFrames
DisGeNET_df = pd.read_csv('DisGeNET_table.txt', delimiter='\t')
GeDiPNet_df = pd.read_csv('GeDiPNet_2023_table.txt', delimiter='\t')
Orphanet_df = pd.read_csv('Orphanet_Augmented_2021_table.txt', delimiter='\t')
Virus_Host_df = pd.read_csv('Virus-Host_PPI_P-HIPSTer_2020_table.txt', delimiter='\t')


# Renombrar la columna 'Term' para cada DataFrame
DisGeNET_df = DisGeNET_df.rename(columns={'Term': 'DisGeNET_Term'})
GeDiPNet_df = GeDiPNet_df.rename(columns={'Term': 'GeDiPNet_Term'})
Orphanet_df = Orphanet_df.rename(columns={'Term': 'Orphanet_Term'})
Virus_Host_df = Virus_Host_df.rename(columns={'Term': 'Virus_Host_Term'})


# Número de filas antes del filtrado
print("DisGeNET antes:", len(DisGeNET_df))
print("GeDiPNet antes:", len(GeDiPNet_df))
print("Orphanet antes:", len(Orphanet_df))
print("Virus_Host antes:", len(Virus_Host_df))

# Filtrar cada DataFrame por 'Adjusted P-value' < 0.05
DisGeNET = DisGeNET_df[DisGeNET_df['Adjusted P-value'] < 0.05]
GeDiPNet = GeDiPNet_df[GeDiPNet_df['Adjusted P-value'] < 0.05]
Orphanet = Orphanet_df[Orphanet_df['Adjusted P-value'] < 0.05]
Virus_Host= Virus_Host_df[Virus_Host_df['Adjusted P-value'] < 0.05]


# Número de filas después del filtrado
print("DisGeNET después:", len(DisGeNET))
print("GeDiPNet después:", len(GeDiPNet))
print("Orphanet después:", len(Orphanet))
print("Virus_Host después:", len(Virus_Host))


# Expandir listas de genes en todos los DataFrames
DisGeNET = expand_genes(DisGeNET, 'Genes')
GeDiPNet = expand_genes(GeDiPNet, 'Genes')
Orphanet = expand_genes(Orphanet, 'Genes')
Virus_Host = expand_genes(Virus_Host, 'Genes')

# Verificar si todos los valores filtrados cumplen con la condición
print("DisGeNET validación:", (DisGeNET['Adjusted P-value'] < 0.05).all())
print("GeDiPNet validación:", (GeDiPNet['Adjusted P-value'] < 0.05).all())
print("Orphanet validación:", (Orphanet['Adjusted P-value'] < 0.05).all())
print("Virus_Host validación:", (Virus_Host['Adjusted P-value'] < 0.05).all())
# Out:
# DisGeNET antes: 3082
# GeDiPNet antes: 708
# Orphanet antes: 2152
# Virus_Host antes: 1534
# DisGeNET después: 33
# GeDiPNet después: 10
# Orphanet después: 122
# Virus_Host después: 0
# DisGeNET validación: True
# GeDiPNet validación: True
# Orphanet validación: True
# Virus_Host validación: True

# %%
# Ejemplo para optimizar columnas y tipos de datos
def optimize_memory(df):
    # Convertir las columnas de tipo objeto (string) a categorías si es posible
    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].astype('category')
    return df

DisGeNET_df = optimize_memory(DisGeNET)
GeDiPNet_df = optimize_memory(GeDiPNet)
Orphanet_df = optimize_memory(Orphanet)
Virus_Host_df = optimize_memory(Virus_Host)

# %%
Virus_Host_df
# Out:
# Empty DataFrame
# Columns: [Virus_Host_Term, Overlap, P-value, Adjusted P-value, Old P-value, Old Adjusted P-value, Odds Ratio, Combined Score, Genes]
# Index: []

# %%
GeDiPNet_df
# Out:
#                                         GeDiPNet_Term Overlap   P-value  \
# 0                          Anomalous Pulmonary Artery    4/14  0.000014
# 1                          Anomalous Pulmonary Artery    4/14  0.000014
# 2                          Anomalous Pulmonary Artery    4/14  0.000014
# 3                          Anomalous Pulmonary Artery    4/14  0.000014
# 4    Congenital Anomalies Of Kidney And Urinary Tract    4/16  0.000024
# ..                                                ...     ...       ...
# 116                              Lymphocytic Leukemia   7/132  0.000689
# 117                              Lymphocytic Leukemia   7/132  0.000689
# 118                              Lymphocytic Leukemia   7/132  0.000689
# 119                              Lymphocytic Leukemia   7/132  0.000689
# 120                              Lymphocytic Leukemia   7/132  0.000689
#
#      Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0            0.007586            0                     0   36.271560
# 1            0.007586            0                     0   36.271560
# 2            0.007586            0                     0   36.271560
# 3            0.007586            0                     0   36.271560
# 4            0.007586            0                     0   30.223242
# ..                ...          ...                   ...         ...
# 116          0.048768            0                     0    5.118921
# 117          0.048768            0                     0    5.118921
# 118          0.048768            0                     0    5.118921
# 119          0.048768            0                     0    5.118921
# 120          0.048768            0                     0    5.118921
#
#      Combined Score    Genes
# 0        406.563842    KITLG
# 1        406.563842   B3GLCT
# 2        406.563842    SNAI2
# 3        406.563842      ENG
# 4        321.227849     SIX2
# ..              ...      ...
# 116       37.268511  GRAMD1B
# 117       37.268511    GPR37
# 118       37.268511    CCND1
# 119       37.268511      BMF
# 120       37.268511     RHOU
#
# [121 rows x 9 columns]

# %%
DisGeNET_df = DisGeNET_df.drop_duplicates()
GeDiPNet_df = GeDiPNet_df.drop_duplicates()
Orphanet_df = Orphanet_df.drop_duplicates()
Virus_Host_df = Virus_Host_df.drop_duplicates()

# %%
# Agrupar, concatenar términos y sus respectivos P-values ajustados
DisGeNET_agg = DisGeNET_df.groupby('Genes').agg({
    'DisGeNET_Term': lambda x: '; '.join(x),
    'Adjusted P-value': lambda x: '; '.join(x.astype(str))
}).reset_index().rename(columns={'Adjusted P-value': 'DisGeNET_Pvalue_Adjusted'})

GeDiPNet_agg = GeDiPNet_df.groupby('Genes').agg({
    'GeDiPNet_Term': lambda x: '; '.join(x),
    'Adjusted P-value': lambda x: '; '.join(x.astype(str))
}).reset_index().rename(columns={'Adjusted P-value': 'GeDiPNet_Pvalue_Adjusted'})

Orphanet_agg = Orphanet_df.groupby('Genes').agg({
    'Orphanet_Term': lambda x: '; '.join(x),
    'Adjusted P-value': lambda x: '; '.join(x.astype(str))
}).reset_index().rename(columns={'Adjusted P-value': 'Orphanet_Pvalue_Adjusted'})

Virus_Host_agg = Virus_Host_df.groupby('Genes').agg({
    'Virus_Host_Term': lambda x: '; '.join(x),
    'Adjusted P-value': lambda x: '; '.join(x.astype(str))
}).reset_index().rename(columns={'Adjusted P-value': 'Virus_Host_Pvalue_Adjusted'})
# Out:
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\3640344149.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   DisGeNET_agg = DisGeNET_df.groupby('Genes').agg({
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\3640344149.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   GeDiPNet_agg = GeDiPNet_df.groupby('Genes').agg({
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\3640344149.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Orphanet_agg = Orphanet_df.groupby('Genes').agg({
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\3640344149.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Virus_Host_agg = Virus_Host_df.groupby('Genes').agg({

# %%
Orphanet_agg
# Out:
#        Genes                                      Orphanet_Term  \
# 0      ABCC2  Autosomal recessive infantile hypercalcemia OR...
# 1   ADAMTS15  SIX2-related frontonasal dysplasia ORPHA:48843...
# 2     AMOTL2  Atrial septal defect, ostium primum type ORPHA...
# 3     ARRDC4  Familial multiple nevi flammei ORPHA:624; Stur...
# 4      BFSP1  Early-onset nuclear cataract ORPHA:98991; Cran...
# ..       ...                                                ...
# 65   TSC22D1  Familial multiple nevi flammei ORPHA:624; Resi...
# 66     VGLL3         Congenital short bowel syndrome ORPHA:2301
# 67     WNT9A    SIX2-related frontonasal dysplasia ORPHA:488437
# 68     ZBED2  Odonto-onycho-dermal dysplasia ORPHA:2721; Sch...
# 69    ZNF703  Craniosynostosis, Boston type ORPHA:1541; Pari...
#
#                              Orphanet_Pvalue_Adjusted
# 0                                  0.0083045131203191
# 1   0.00518481975049; 0.00518481975049; 0.00518481...
# 2   0.0040361447187818; 0.00518481975049; 0.005184...
# 3              0.0180064224283883; 0.0180064224283883
# 4   0.0179885731122231; 0.0180064224283883; 0.0180...
# ..                                                ...
# 65  0.0180064224283883; 0.0180064224283883; 0.0180...
# 66                                 0.0083045131203191
# 67                                   0.00518481975049
# 68             0.0180064224283883; 0.0180064224283883
# 69             0.0180064224283883; 0.0180064224283883
#
# [70 rows x 3 columns]

# %%
merged_df = DisGeNET_agg
merged_df = pd.merge(merged_df, GeDiPNet_agg, on='Genes', how='outer')
merged_df = pd.merge(merged_df, Orphanet_agg, on='Genes', how='outer')
merged_df = pd.merge(merged_df, Virus_Host_agg, on='Genes', how='outer')

# %%
merged_df
# Out:
#        Genes                                      DisGeNET_Term  \
# 0      AANAT  Colorectal Carcinoma; Breast Carcinoma; Colore...
# 1      ABCB1  Colorectal Carcinoma; Mammary Neoplasms; Ovari...
# 2      ABCC2  Colorectal Carcinoma; Mammary Neoplasms; Ovari...
# 3      ACSL5  Colorectal Carcinoma; Epithelioma; Colorectal ...
# 4      ACTA2  Mammary Neoplasms; Breast Carcinoma; Adenocarc...
# ..       ...                                                ...
# 152    WNT9A                                  Mammary Neoplasms
# 153    ZBED2                                                NaN
# 154   ZBTB18                                    Medulloblastoma
# 155  ZCCHC12                                                NaN
# 156   ZNF703  Mammary Neoplasms; Breast Carcinoma; Malignant...
#
#                               DisGeNET_Pvalue_Adjusted  \
# 0    0.0034602840073026; 0.0042545616049287; 0.0149...
# 1    0.0034602840073026; 0.0034602840073026; 0.0034...
# 2    0.0034602840073026; 0.0034602840073026; 0.0034...
# 3    0.0034602840073026; 0.0149002095788623; 0.0149...
# 4    0.0034602840073026; 0.0042545616049287; 0.0155...
# ..                                                 ...
# 152                                 0.0034602840073026
# 153                                                NaN
# 154                                 0.0354767239335874
# 155                                                NaN
# 156  0.0034602840073026; 0.0042545616049287; 0.0191...
#
#                                          GeDiPNet_Term  \
# 0                                                  NaN
# 1    Breast Carcinoma; Esophagus Neoplasm; Marfan S...
# 2                                   Esophagus Neoplasm
# 3                                                  NaN
# 4    Breast Carcinoma; Marfan Syndrome; Mammary Neo...
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                 Esophagus Neoplasm
# 156                                                NaN
#
#                               GeDiPNet_Pvalue_Adjusted  \
# 0                                                  NaN
# 1    0.0075861267486594; 0.0102679590519094; 0.0133...
# 2                                   0.0102679590519094
# 3                                                  NaN
# 4    0.0075861267486594; 0.0133304506157067; 0.0155...
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                 0.0102679590519094
# 156                                                NaN
#
#                                          Orphanet_Term  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Autosomal recessive infantile hypercalcemia OR...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152    SIX2-related frontonasal dysplasia ORPHA:488437
# 153  Odonto-onycho-dermal dysplasia ORPHA:2721; Sch...
# 154                                                NaN
# 155                                                NaN
# 156  Craniosynostosis, Boston type ORPHA:1541; Pari...
#
#                    Orphanet_Pvalue_Adjusted Virus_Host_Term  \
# 0                                       NaN             NaN
# 1                                       NaN             NaN
# 2                        0.0083045131203191             NaN
# 3                                       NaN             NaN
# 4                                       NaN             NaN
# ..                                      ...             ...
# 152                        0.00518481975049             NaN
# 153  0.0180064224283883; 0.0180064224283883             NaN
# 154                                     NaN             NaN
# 155                                     NaN             NaN
# 156  0.0180064224283883; 0.0180064224283883             NaN
#
#      Virus_Host_Pvalue_Adjusted
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 152                         NaN
# 153                         NaN
# 154                         NaN
# 155                         NaN
# 156                         NaN
#
# [157 rows x 9 columns]

# %%
# Llenamos los valores nulos de 'Interactor A Genes' y 'Interactor B Genes' con una cadena vacía
Intact_df_reducido['Interactor A Genes'].fillna('', inplace=True)
Intact_df_reducido['Interactor B Genes'].fillna('', inplace=True)

# Unimos los genes en una sola columna, eliminando duplicados
Intact_df_reducido['Genes'] = Intact_df_reducido[['Interactor A Genes', 'Interactor B Genes']].apply(
    lambda x: ';'.join(sorted(set(filter(None, x)))), axis=1)

# Convertir todas las columnas a tipo string para evitar problemas en la concatenación
Intact_df_reducido = Intact_df_reducido.astype(str)

# Agrupamos por 'Genes' y combinamos los valores de las demás columnas eliminando duplicados
Intact_df_grouped = Intact_df_reducido.groupby('Genes').agg({
    'Host organism(s)': lambda x: ';'.join(sorted(set(x))),
    'Confidence value(s)': lambda x: ';'.join(sorted(set(x))),
    'Taxid interactor A': lambda x: ';'.join(sorted(set(x))),
    'Taxid interactor B': lambda x: ';'.join(sorted(set(x)))
}).reset_index()
# Out:
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\2496710363.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Intact_df_reducido['Interactor A Genes'].fillna('', inplace=True)
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\2496710363.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Intact_df_reducido['Interactor A Genes'].fillna('', inplace=True)
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\2496710363.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Intact_df_reducido['Interactor B Genes'].fillna('', inplace=True)
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\2496710363.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Intact_df_reducido['Interactor B Genes'].fillna('', inplace=True)
# C:\Users\3060\AppData\Local\Temp\ipykernel_23560\2496710363.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Intact_df_reducido['Genes'] = Intact_df_reducido[['Interactor A Genes', 'Interactor B Genes']].apply(

# %%
Intact_df_grouped
# Out:
#             Genes                                   Host organism(s)  \
# 0       A1CF;OIP5                                              yeasx
# 1      A1bg;SETD7                                              yeasx
# 2        A2M;H2AX                           Saccharomyces cerevisiae
# 3        A2M;TGM2                                              yeasx
# 4     A2M;TSC22D1                           Saccharomyces cerevisiae
# ...           ...                                                ...
# 8920    ZW10;napA  Homo sapiens HCT116 colon carcinoma cell;Homo ...
# 8921     ZW10;rep              Homo sapiens A549 lung carcinoma cell
# 8922    ZW10;uvrB                                              yeasx
# 8923         stn1  Homo sapiens HeLa epitheloid cervical carcinom...
# 8924    stn1;ten1  Homo sapiens;Homo sapiens HCT116 colon carcino...
#
#      Confidence value(s) Taxid interactor A  \
# 0                   0.56       Homo sapiens
# 1                   0.37       Homo sapiens
# 2                   0.37       Homo sapiens
# 3                   0.37       Homo sapiens
# 4                   0.37       Homo sapiens
# ...                  ...                ...
# 8920                0.53       Homo sapiens
# 8921                0.35         SARS-CoV-2
# 8922                0.37       Homo sapiens
# 8923           0.35;0.56       Homo sapiens
# 8924                0.88       Homo sapiens
#
#                             Taxid interactor B
# 0                                 Homo sapiens
# 1                                 Homo sapiens
# 2                                 Homo sapiens
# 3                                 Homo sapiens
# 4                                 Homo sapiens
# ...                                        ...
# 8920                              Homo sapiens
# 8921                              Homo sapiens
# 8922  Francisella tularensis subsp. tularensis
# 8923                              Homo sapiens
# 8924                              Homo sapiens
#
# [8925 rows x 5 columns]

# %%
# Añadimos el sufijo '_Intact' a las columnas del DataFrame agrupado
Intact_df_grouped = Intact_df_grouped.add_suffix('_Intact')
Intact_df_grouped = Intact_df_grouped.rename(columns={'Genes_Intact': 'Genes'})

# Realizamos el merge con el DataFrame merged_df
final_merged_df = pd.merge(merged_df, Intact_df_grouped, on='Genes', how='left')

# %%
# Mostrar el DataFrame resultante
final_merged_df
# Out:
#        Genes                                      DisGeNET_Term  \
# 0      AANAT  Colorectal Carcinoma; Breast Carcinoma; Colore...
# 1      ABCB1  Colorectal Carcinoma; Mammary Neoplasms; Ovari...
# 2      ABCC2  Colorectal Carcinoma; Mammary Neoplasms; Ovari...
# 3      ACSL5  Colorectal Carcinoma; Epithelioma; Colorectal ...
# 4      ACTA2  Mammary Neoplasms; Breast Carcinoma; Adenocarc...
# ..       ...                                                ...
# 152    WNT9A                                  Mammary Neoplasms
# 153    ZBED2                                                NaN
# 154   ZBTB18                                    Medulloblastoma
# 155  ZCCHC12                                                NaN
# 156   ZNF703  Mammary Neoplasms; Breast Carcinoma; Malignant...
#
#                               DisGeNET_Pvalue_Adjusted  \
# 0    0.0034602840073026; 0.0042545616049287; 0.0149...
# 1    0.0034602840073026; 0.0034602840073026; 0.0034...
# 2    0.0034602840073026; 0.0034602840073026; 0.0034...
# 3    0.0034602840073026; 0.0149002095788623; 0.0149...
# 4    0.0034602840073026; 0.0042545616049287; 0.0155...
# ..                                                 ...
# 152                                 0.0034602840073026
# 153                                                NaN
# 154                                 0.0354767239335874
# 155                                                NaN
# 156  0.0034602840073026; 0.0042545616049287; 0.0191...
#
#                                          GeDiPNet_Term  \
# 0                                                  NaN
# 1    Breast Carcinoma; Esophagus Neoplasm; Marfan S...
# 2                                   Esophagus Neoplasm
# 3                                                  NaN
# 4    Breast Carcinoma; Marfan Syndrome; Mammary Neo...
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                 Esophagus Neoplasm
# 156                                                NaN
#
#                               GeDiPNet_Pvalue_Adjusted  \
# 0                                                  NaN
# 1    0.0075861267486594; 0.0102679590519094; 0.0133...
# 2                                   0.0102679590519094
# 3                                                  NaN
# 4    0.0075861267486594; 0.0133304506157067; 0.0155...
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                 0.0102679590519094
# 156                                                NaN
#
#                                          Orphanet_Term  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Autosomal recessive infantile hypercalcemia OR...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 152    SIX2-related frontonasal dysplasia ORPHA:488437
# 153  Odonto-onycho-dermal dysplasia ORPHA:2721; Sch...
# 154                                                NaN
# 155                                                NaN
# 156  Craniosynostosis, Boston type ORPHA:1541; Pari...
#
#                    Orphanet_Pvalue_Adjusted Virus_Host_Term  \
# 0                                       NaN             NaN
# 1                                       NaN             NaN
# 2                        0.0083045131203191             NaN
# 3                                       NaN             NaN
# 4                                       NaN             NaN
# ..                                      ...             ...
# 152                        0.00518481975049             NaN
# 153  0.0180064224283883; 0.0180064224283883             NaN
# 154                                     NaN             NaN
# 155                                     NaN             NaN
# 156  0.0180064224283883; 0.0180064224283883             NaN
#
#      Virus_Host_Pvalue_Adjusted  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 152                         NaN
# 153                         NaN
# 154                         NaN
# 155                         NaN
# 156                         NaN
#
#                                Host organism(s)_Intact  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                             In vitro
# 4    Homo sapiens HEK293 embryonic kidney cell;In v...
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154  Homo sapiens SNB-19 glioblastoma cell;Homo sap...
# 155                                                NaN
# 156         Homo sapiens HEK293T embryonic kidney cell
#
#     Confidence value(s)_Intact  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                         0.35
# 4                    0.35;0.37
# ..                         ...
# 152                        NaN
# 153                        NaN
# 154              0.35;0.4;0.53
# 155                        NaN
# 156                       0.35
#
#                              Taxid interactor A_Intact  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                   chemical synthesis
# 4    Dengue virus 2;Homo sapiens;chemical synthesis...
# ..                                                 ...
# 152                                                NaN
# 153                                                NaN
# 154                                       Homo sapiens
# 155                                                NaN
# 156                                       Homo sapiens
#
#         Taxid interactor B_Intact
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                    Homo sapiens
# 4    Homo sapiens;Yersinia pestis
# ..                            ...
# 152                           NaN
# 153                           NaN
# 154                  Homo sapiens
# 155                           NaN
# 156                  Homo sapiens
#
# [157 rows x 13 columns]

# %%
# Guardar el DataFrame final en un archivo CSV
final_merged_df.to_csv('Integracion_con_patógenos_y_enfermedades_Fusobacterium_Nucleatum_Padj_menor_0.05.csv', index=False)

# %%
# Leer el archivo CSV en un DataFrame
final_merged_df = pd.read_csv('Integracion_con_patógenos_y_enfermedades_Fusobacterium_Nucleatum_Padj_menor_0.05.csv')

# Mostrar las primeras filas del DataFrame para verificar la carga
final_merged_df.head()
# Out:
#    Genes                                      DisGeNET_Term  \
# 0  AANAT  Colorectal Carcinoma; Breast Carcinoma; Colore...
# 1  ABCB1  Colorectal Carcinoma; Mammary Neoplasms; Ovari...
# 2  ABCC2  Colorectal Carcinoma; Mammary Neoplasms; Ovari...
# 3  ACSL5  Colorectal Carcinoma; Epithelioma; Colorectal ...
# 4  ACTA2  Mammary Neoplasms; Breast Carcinoma; Adenocarc...
#
#                             DisGeNET_Pvalue_Adjusted  \
# 0  0.0034602840073026; 0.0042545616049287; 0.0149...
# 1  0.0034602840073026; 0.0034602840073026; 0.0034...
# 2  0.0034602840073026; 0.0034602840073026; 0.0034...
# 3  0.0034602840073026; 0.0149002095788623; 0.0149...
# 4  0.0034602840073026; 0.0042545616049287; 0.0155...
#
#                                        GeDiPNet_Term  \
# 0                                                NaN
# 1  Breast Carcinoma; Esophagus Neoplasm; Marfan S...
# 2                                 Esophagus Neoplasm
# 3                                                NaN
# 4  Breast Carcinoma; Marfan Syndrome; Mammary Neo...
#
#                             GeDiPNet_Pvalue_Adjusted  \
# 0                                                NaN
# 1  0.0075861267486594; 0.0102679590519094; 0.0133...
# 2                                 0.0102679590519094
# 3                                                NaN
# 4  0.0075861267486594; 0.0133304506157067; 0.0155...
#
#                                        Orphanet_Term Orphanet_Pvalue_Adjusted  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2  Autosomal recessive infantile hypercalcemia OR...       0.0083045131203191
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#    Virus_Host_Term  Virus_Host_Pvalue_Adjusted  \
# 0              NaN                         NaN
# 1              NaN                         NaN
# 2              NaN                         NaN
# 3              NaN                         NaN
# 4              NaN                         NaN
#
#                              Host organism(s)_Intact  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                           In vitro
# 4  Homo sapiens HEK293 embryonic kidney cell;In v...
#
#   Confidence value(s)_Intact  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                       0.35
# 4                  0.35;0.37
#
#                            Taxid interactor A_Intact  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                 chemical synthesis
# 4  Dengue virus 2;Homo sapiens;chemical synthesis...
#
#       Taxid interactor B_Intact
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                  Homo sapiens
# 4  Homo sapiens;Yersinia pestis

# %%
# Diccionario de categorías de enfermedades actualizado
disease_categories = {
    "Cáncer": ["carcinoma", "cancer", "tumor", "neoplasm", "leukemia", "lymphoma", "sarcoma", "melanoma"],
    "Enfermedades Infecciosas": ["infection", "viral", "bacterial", "fungal", "parasitic", "malaria", "HIV", "bacteria", "tuberculosis"],
    "Enfermedades Inmunológicas": ["autoimmune", "lupus", "rheumatoid", "asthma", "allergy", "immunodeficiency"],
    "Enfermedades Neurológicas": ["neurological", "amyotrophic", "parkinson", "alzheimer", "epilepsy", "schizophrenia", "bipolar disorder", "autism"],
    "Enfermedades Cardiovasculares": ["cardiovascular", "heart", "hypertension", "myocardial", "stroke", "angina"],
    "Enfermedades Renales": ["kidney failure", "nephropathy", "glomerulonephritis", "nephrotic syndrome"],
    "Trastornos Metabólicos": ["amyloidosis", "glycogen storage disease", "citrullinemia"],
    "Trastornos Genéticos": ["Ehlers-Danlos syndrome", "Charcot-Marie-Tooth disease", "epidermolysis bullosa"],
    "Trastornos de la Piel": ["dermatitis", "ichthyosis", "erythrokeratodermia"],
    "Enfermedades asociadas a la microbiota": [
        "dysbiosis", "gut microbiota", "intestinal microbiota", "helicobacter pylori", "necrotizing enterocolitis", 
        "inflammatory bowel disease", "celiac disease", "acute diarrhea", "non-alcoholic fatty liver disease", 
        "irritable bowel syndrome", "obesity", "diabetes", "inflammatory intestinal disease", 
        "stress", "anxiety", "digestive system", "poor diet", "fiber deficiency", 
        "sedentarism", "alcohol", "tobacco", "diarrhea", "cramps", "constipation"
    ],
    "Otras Enfermedades": []  # Aquí se incluirán enfermedades no clasificadas anteriormente
}

# %%
def classify_disease(disease_terms, categories):
    # Si el término es NaN, retornamos 'other'
    if pd.isna(disease_terms):
        return 'Sin información'
    
    # Dividir los términos por ';' y clasificar cada uno
    terms = disease_terms.split(';')
    categories_found = set()
    for term in terms:
        term = term.strip()  # Limpiar espacios en blanco
        for category, keywords in categories.items():
            if any(keyword.lower() in term.lower() for keyword in keywords):
                categories_found.add(category)
                break  # No necesitamos verificar más categorías para este término
    if not categories_found:
        return 'other'
    return '; '.join(categories_found)  # Unir las categorías encontradas en una cadena

# %%
def classify_diseases(row, categories):
    classified_terms = {}
    for col in row.index:
        if 'Term' in col:  # Solo para columnas que contienen términos de enfermedades
            classified_terms[col + '_Category'] = classify_disease(row[col], categories)
    return pd.Series(classified_terms)

# Aplicar la clasificación al DataFrame
classification_df = final_merged_df.apply(classify_diseases, categories=disease_categories, axis=1)

# Agregar las clasificaciones al DataFrame original
final_merged_df = final_merged_df.join(classification_df)

# Mostrar el DataFrame resultante con las nuevas categorías
final_merged_df.head()
# Out:
#    Genes                                      DisGeNET_Term  \
# 0  AANAT  Colorectal Carcinoma; Breast Carcinoma; Colore...
# 1  ABCB1  Colorectal Carcinoma; Mammary Neoplasms; Ovari...
# 2  ABCC2  Colorectal Carcinoma; Mammary Neoplasms; Ovari...
# 3  ACSL5  Colorectal Carcinoma; Epithelioma; Colorectal ...
# 4  ACTA2  Mammary Neoplasms; Breast Carcinoma; Adenocarc...
#
#                             DisGeNET_Pvalue_Adjusted  \
# 0  0.0034602840073026; 0.0042545616049287; 0.0149...
# 1  0.0034602840073026; 0.0034602840073026; 0.0034...
# 2  0.0034602840073026; 0.0034602840073026; 0.0034...
# 3  0.0034602840073026; 0.0149002095788623; 0.0149...
# 4  0.0034602840073026; 0.0042545616049287; 0.0155...
#
#                                        GeDiPNet_Term  \
# 0                                                NaN
# 1  Breast Carcinoma; Esophagus Neoplasm; Marfan S...
# 2                                 Esophagus Neoplasm
# 3                                                NaN
# 4  Breast Carcinoma; Marfan Syndrome; Mammary Neo...
#
#                             GeDiPNet_Pvalue_Adjusted  \
# 0                                                NaN
# 1  0.0075861267486594; 0.0102679590519094; 0.0133...
# 2                                 0.0102679590519094
# 3                                                NaN
# 4  0.0075861267486594; 0.0133304506157067; 0.0155...
#
#                                        Orphanet_Term Orphanet_Pvalue_Adjusted  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2  Autosomal recessive infantile hypercalcemia OR...       0.0083045131203191
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#    Virus_Host_Term  Virus_Host_Pvalue_Adjusted  \
# 0              NaN                         NaN
# 1              NaN                         NaN
# 2              NaN                         NaN
# 3              NaN                         NaN
# 4              NaN                         NaN
#
#                              Host organism(s)_Intact  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                           In vitro
# 4  Homo sapiens HEK293 embryonic kidney cell;In v...
#
#   Confidence value(s)_Intact  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                       0.35
# 4                  0.35;0.37
#
#                            Taxid interactor A_Intact  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                 chemical synthesis
# 4  Dengue virus 2;Homo sapiens;chemical synthesis...
#
#       Taxid interactor B_Intact            DisGeNET_Term_Category  \
# 0                           NaN                            Cáncer
# 1                           NaN  Cáncer; Enfermedades Infecciosas
# 2                           NaN                            Cáncer
# 3                  Homo sapiens                            Cáncer
# 4  Homo sapiens;Yersinia pestis                            Cáncer
#
#   GeDiPNet_Term_Category Orphanet_Term_Category Virus_Host_Term_Category
# 0        Sin información        Sin información          Sin información
# 1                 Cáncer        Sin información          Sin información
# 2                 Cáncer                  other          Sin información
# 3        Sin información        Sin información          Sin información
# 4                 Cáncer        Sin información          Sin información
