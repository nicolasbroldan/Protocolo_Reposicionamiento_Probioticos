# %%
if (!require("BiocManager", quietly = TRUE))
  install.packages("BiocManager")
BiocManager::install

# %%
BiocManager::install("biomaRt")
library(biomaRt)

# %%
library(BiocManager)
BiocManager::install('GOstats')
BiocManager::install("clusterProfiler")
BiocManager::install("org.Hs.eg.db")
BiocManager::install("enrichplot")
#BiocManager::install("Rtools")

# %%
# Leer el archivo CSV
data <- read.csv("deSeqRes_filtrado_bacillus_subtilis_CW14.csv")
# Filtrar los genes significativos
genes_significativos <- subset(data, padj < 0.05)
# Extraer la lista de genes significativos
lista_genes <- genes_significativos$gene_name
# Verificar si los genes son números (posiblemente IDs de Entrez)
if (all(grepl("^\\d+$", lista_genes))) {
    genes_ids <- lista_genes
} else {
    # Convertir los nombres de genes a IDs de Entrez si son símbolos
    genes_ids <- bitr(lista_genes, fromType = "SYMBOL", toType = "ENTREZID", OrgDb = org.Hs.eg.db)$ENTREZID
}
genes_ids
# Out:
#   [1]      5997       133      7124      2353      4576      4572     10769
#   [8]    414236      3659      4569      3397      1435      4050    284454
#  [15]    780851      1543    389384     10808     27289      3576     10370
#  [22]      3311      1437 112268133      2920      4792      6385     64332
#  [29]      4556      3627    148022      5328     79094    162989     84981
#  [36]      1545      9298      6376      6776 105372652 112268301      7128
#  [43] 105373485      1827    283624      4566 105377347      6352      3139
#  [50]      2921       624      1844     63943 105374418     85389       330
#  [57]      8740      2919     85390 100874246     11080      4555 105378604
#  [64] 101928433      6351 107986649      3310    780853      7127      3553
#  [71]     83896    407975        12      4568 107075116 105376361 102465879
#  [78]      3383 107986119      8013 105373836    693201     92162      4565
#  [85]      6373      9935      1440    158257    171523      9001      6367
#  [92]    114599     81788     83887    116938     91370 100419583    441307
#  [99]     79635 105376360     10747    340719    284185      3337 100130476
# [106] 100996511 100616376 100422943     25794    254100     51561    135112
# [113]      6274 105372711     26813 105378328      9308      3303 107986170
# [120]      8351      4577      6347      2824    441072 105378744     22943
# [127] 107984421     26013      3304 101927080 105369161      8676     26816
# [134]     65997      2113 100216546 101928741      5724 105374584      6648
# [141] 107986197      3626       629    692158      7057     84688    339829
# [148]     26817 107987152    340544      6374 105372380      5021 107985080
# [155]    677806 101930112      2302 105373944     26330 100126791    677812
# [162] 105371159      9299 100505812     85450 101929715 100287216 100506178
# [169]      3976    574042 105375181    728378     26770      6344      9297
# [176] 105370364     26818 105371413    342977    619569    677811 105376714
# [183]     54863    387763 100507489      3552 107985383 105371058 105378911
# [190]      6364    677810 105377290      4884     23025 105371600     57172
# [197]      9953    594838

# %%
install.packages("biomaRt")

# %%
install.packages("org.Hs.eg.db")

# %%
library(biomaRt)
library(org.Hs.eg.db)
# Convertir los IDs de Entrez a nombres de genes si son IDs de Entrez
if (all(grepl("^\\d+$", genes_ids))) {
    # Crear una conexión a la base de datos de biomart
    mart <- useMart(biomart = "ensembl", dataset = "hsapiens_gene_ensembl")
    
    # Obtener los nombres de los genes correspondientes a los IDs de Entrez
    gene_info <- getBM(attributes = c("entrezgene_id", "external_gene_name"), 
                       filters = "entrezgene_id", 
                       values = genes_ids, 
                       mart = mart)
    
    # Reemplazar los IDs de Entrez por los nombres de los genes convertidos
    genes_names <- gene_info$external_gene_name
}
# Out:
# Loading required package: AnnotationDbi
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: 'BiocGenerics'
#
#
# The following objects are masked from 'package:stats':
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from 'package:base':
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: IRanges
#
# Loading required package: S4Vectors
#
#
# Attaching package: 'S4Vectors'
#
#
# The following object is masked from 'package:utils':
#
#     findMatches
#
#
# The following objects are masked from 'package:base':
#
#     expand.grid, I, unname
#
#
#
# Attaching package: 'IRanges'
#
#
# The following object is masked from 'package:grDevices':
#
#     windows

# %%
genes_names
# Out:
#   [1] "EGOT"         "WAKMAR2"      "MIR3189"      "CARD8-AS1"    "STEAP1B-AS1"
#   [6] "MIR4492"      "ARHGAP31-AS1" "SPG7"         "MIR8085"      "CITED2"
#  [11] ""             "LINC01767"    "MIR3142HG"    "MASP2"        "PLK2"
#  [16] "HSPH1"        "DNAJB4"       "SNORD15B"     "SNORD83B"     "SERPINA3"
#  [21] "ADM"          "NCOA7"        "CSF1"         "CSF2"         "CSF3"
#  [26] "TICAM1"       "CYP1A1"       "CYP1B1"       "LINC02603"    "DEDD2"
#  [31] "CYP2T1P"      "RCAN1"        "DUSP2"        "ETS1"         "DKK1"
#  [36] "FOXJ1"        "UNC13A"       "FOS"          "FSCN2"        "L3MBTL1"
#  [41] "GAPDHS"       "SNORD36C"     "SNORD35A"     "SNORD34"      "SNORD33"
#  [46] "RND1"         "GPM6B"        "LINC00641"    "CXCL1"        "CXCL2"
#  [51] "CXCL3"        "HLA-L"        "BIRC3"        "HSPA1A"       "HSPA1B"
#  [56] "HSPA6"        "DNAJB1"       "ICAM1"        "ID1"          "CCDC39"
#  [61] "NANOS1"       "NANOS3"       "IL1A"         "IL1B"         "CXCL8"
#  [66] "INHBC"        "CXCL10"       "IRF1"         "C11orf96"     "BNIP5"
#  [71] "LIF"          "LTB"          "MIR17HG"      "C10orf55"     "IL6ST-DT"
#  [76] "PDGFA-DT"     "NFKBIA"       "NPTX1"        "OXTR"         "IL23A"
#  [81] "PLAU"         "TOR4A"        "CAMK1G"       "PTAFR"        "SNORA10"
#  [86] "SNORD100"     "RGS2"         "SNORA41"      "BDKRB2"       "S100A3"
#  [91] "CFB"          "SCTR"         "CCL2"         "CCL4"         "CCL5"
#  [96] "CCL20"        "CCL22"        "CXCL11"       "CXCL5"        "CX3CL1"
# [101] "SDC4"         "FKBPL"        "NFKBIZ"       "RASL11B"      "SOD2"
# [106] "STAT5A"       "SNORA20"      "SNORA26"      "SNORA28"      "SNORA29"
# [111] "SNORA57"      "MIR616"       "THBS1"        "TNF"          "TNFAIP2"
# [116] "TNFAIP3"      "POTEF"        "CHAC1"        "CCDC121"      "NR4A3"
# [121] "NUAK2"        "H3C4"         "TTLL2"        "KRTAP3-1"     "SPMIP6"
# [126] "MIR22HG"      "SNORD14C"     "SNORD14D"     "ITPRIP"       "STX11"
# [131] "TNFSF14"      "HAP1"         "LIF-AS2"      "TMEM88"       "SNORD30"
# [136] "CD83"         "MAFB"         "HS3ST3B1"

# %%
# Conectarse a la base de datos UniProt usando el conjunto de datos 'hsapiens_gene_ensembl'
ensembl <- useMart("ensembl", dataset = "hsapiens_gene_ensembl")

# %%
# Obtener la información de las proteínas correspondientes a los nombres de los genes
info_proteinas <- getBM(attributes = c("ensembl_gene_id", "external_gene_name", "uniprotswissprot", "description"),
                        filters = "external_gene_name",
                        values = genes_names,
                        mart = mart)

# %%
# Filtrar para obtener solo los genes que codifican proteínas
genes_codifican_proteinas <- info_proteinas[info_proteinas$uniprotswissprot != "", ]

# Mostrar los resultados
genes_codifican_proteinas
# Out:
#     ensembl_gene_id external_gene_name uniprotswissprot
# 1   ENSG00000128342 LIF                P15018
# 2   ENSG00000170345 FOS                P01100
# 4   ENSG00000107984 DKK1               O94907
# 5   ENSG00000124145 SDC4               P31431
# 6   ENSG00000112149 CD83               Q01151
# 8   ENSG00000125968 ID1                P41134
# 9   ENSG00000120694 HSPH1              Q92598
# 11  ENSG00000102962 CCL22              O00626
# 12  ENSG00000111912 NCOA7              Q8NI08
# 14  ENSG00000159200 RCAN1              P53805
# 16  ENSG00000148841 ITPRIP             Q8IWB1
# 18  ENSG00000169403 PTAFR              P25105
# 19  ENSG00000204103 MAFB               Q9Y5Q3
# 20  ENSG00000006210 CX3CL1             P78423
# 22  ENSG00000196136 SERPINA3           P01011
# 25  ENSG00000277943 CCL4               P13236
# 26  ENSG00000185215 TNFAIP2            Q03169
# 28  ENSG00000262068 KRTAP3-1           Q9BYR8
# 30  ENSG00000122861 PLAU               P00749
# 31  ENSG00000198113 TOR4A              Q9NXH8
# 32  ENSG00000275824 CCL4               P13236
# 34  ENSG00000274233 CCL5               P13501
# 37  ENSG00000120440 TTLL2              Q9BWV7
# 38  ENSG00000125538 IL1B               P01584
# 40  ENSG00000128045 RASL11B            Q9BPW5
# 41  ENSG00000125735 TNFSF14            O43557
# 43  ENSG00000108342 CSF3               P09919
# 45  ENSG00000167874 TMEM88             Q6PEY1
# 47  ENSG00000184371 CSF1               P09603
# 48  ENSG00000227507 LTB                Q06643
# ⋮   ⋮               ⋮                  ⋮
# 151 ENSG00000188613 NANOS1             Q8WY41
# 153 ENSG00000291237 SOD2               P04179
# 155 ENSG00000110944 IL23A              Q9NPF7
# 157 ENSG00000172602 RND1               Q92730
# 158 ENSG00000196604 POTEF              A5A3E0
# 160 ENSG00000127666 TICAM1             Q8IUC6
# 161 ENSG00000171246 NPTX1              Q15818
# 164 ENSG00000108691 CCL2               P13500
# 165 ENSG00000164442 CITED2             Q99967
# 167 ENSG00000118503 TNFAIP3            P21580
# 170 ENSG00000125347 IRF1               P10914
# 171 ENSG00000176714 CCDC121            Q6ZUS5
# 173 ENSG00000145632 PLK2               Q9NYY3
# 176 ENSG00000105679 GAPDHS             O14556
# 177 ENSG00000188015 S100A3             P33764
# 179 ENSG00000284862 CCDC39             Q9UFE4
# 180 ENSG00000180914 OXTR               P30559
# 183 ENSG00000275302 CCL4               P13236
# 185 ENSG00000134954 ETS1               P14921
# 188 ENSG00000144802 NFKBIZ             Q9BYH8
# 190 ENSG00000173805 HAP1               P54257
# 191 ENSG00000115008 IL1A               P01583
# 193 ENSG00000023445 BIRC3              Q13489
# 194 ENSG00000271503 CCL5               P13501
# 196 ENSG00000116741 RGS2               P41220
# 197 ENSG00000163545 NUAK2              Q9H093
# 199 ENSG00000009724 MASP2              O00187
# 201 ENSG00000162616 DNAJB4             Q9UDY4
# 202 ENSG00000158050 DUSP2              Q05923
# 203 ENSG00000138061 CYP1B1             Q16678
#     description
# 1   LIF interleukin 6 family cytokine [Source:HGNC Symbol;Acc:HGNC:6596]
# 2   Fos proto-oncogene, AP-1 transcription factor subunit [Source:HGNC Symbol;Acc:HGNC:3796]
# 4   dickkopf WNT signaling pathway inhibitor 1 [Source:HGNC Symbol;Acc:HGNC:2891]
# 5   syndecan 4 [Source:HGNC Symbol;Acc:HGNC:10661]
# 6   CD83 molecule [Source:HGNC Symbol;Acc:HGNC:1703]
# 8   inhibitor of DNA binding 1 [Source:HGNC Symbol;Acc:HGNC:5360]
# 9   heat shock protein family H (Hsp110) member 1 [Source:HGNC Symbol;Acc:HGNC:16969]
# 11  C-C motif chemokine ligand 22 [Source:HGNC Symbol;Acc:HGNC:10621]
# 12  nuclear receptor coactivator 7 [Source:HGNC Symbol;Acc:HGNC:21081]
# 14  regulator of calcineurin 1 [Source:HGNC Symbol;Acc:HGNC:3040]
# 16  inositol 1,4,5-trisphosphate receptor interacting protein [Source:HGNC Symbol;Acc:HGNC:29370]
# 18  platelet activating factor receptor [Source:HGNC Symbol;Acc:HGNC:9582]
# 19  MAF bZIP transcription factor B [Source:HGNC Symbol;Acc:HGNC:6408]
# 20  C-X3-C motif chemokine ligand 1 [Source:HGNC Symbol;Acc:HGNC:10647]
# 22  serpin family A member 3 [Source:HGNC Symbol;Acc:HGNC:16]
# 25  C-C motif chemokine ligand 4 [Source:HGNC Symbol;Acc:HGNC:10630]
# 26  TNF alpha induced protein 2 [Source:HGNC Symbol;Acc:HGNC:11895]
# 28  keratin associated protein 3-1 [Source:HGNC Symbol;Acc:HGNC:16778]
# 30  plasminogen activator, urokinase [Source:HGNC Symbol;Acc:HGNC:9052]
# 31  torsin family 4 member A [Source:HGNC Symbol;Acc:HGNC:25981]
# 32  C-C motif chemokine ligand 4 [Source:HGNC Symbol;Acc:HGNC:10630]
# 34  C-C motif chemokine ligand 5 [Source:HGNC Symbol;Acc:HGNC:10632]
# 37  tubulin tyrosine ligase like 2 [Source:HGNC Symbol;Acc:HGNC:21211]
# 38  interleukin 1 beta [Source:HGNC Symbol;Acc:HGNC:5992]
# 40  RAS like family 11 member B [Source:HGNC Symbol;Acc:HGNC:23804]
# 41  TNF superfamily member 14 [Source:HGNC Symbol;Acc:HGNC:11930]
# 43  colony stimulating factor 3 [Source:HGNC Symbol;Acc:HGNC:2438]
# 45  transmembrane protein 88 [Source:HGNC Symbol;Acc:HGNC:32371]
# 47  colony stimulating factor 1 [Source:HGNC Symbol;Acc:HGNC:2432]
# 48  lymphotoxin beta [Source:HGNC Symbol;Acc:HGNC:6711]
# ⋮   ⋮
# 151 nanos C2HC-type zinc finger 1 [Source:HGNC Symbol;Acc:HGNC:23044]
# 153 superoxide dismutase 2 [Source:HGNC Symbol;Acc:HGNC:11180]
# 155 interleukin 23 subunit alpha [Source:HGNC Symbol;Acc:HGNC:15488]
# 157 Rho family GTPase 1 [Source:HGNC Symbol;Acc:HGNC:18314]
# 158 POTE ankyrin domain family member F [Source:HGNC Symbol;Acc:HGNC:33905]
# 160 TIR domain containing adaptor molecule 1 [Source:HGNC Symbol;Acc:HGNC:18348]
# 161 neuronal pentraxin 1 [Source:HGNC Symbol;Acc:HGNC:7952]
# 164 C-C motif chemokine ligand 2 [Source:HGNC Symbol;Acc:HGNC:10618]
# 165 Cbp/p300 interacting transactivator with Glu/Asp rich carboxy-terminal domain 2 [Source:HGNC Symbol;Acc:HGNC:1987]
# 167 TNF alpha induced protein 3 [Source:HGNC Symbol;Acc:HGNC:11896]
# 170 interferon regulatory factor 1 [Source:HGNC Symbol;Acc:HGNC:6116]
# 171 coiled-coil domain containing 121 [Source:HGNC Symbol;Acc:HGNC:25833]
# 173 polo like kinase 2 [Source:HGNC Symbol;Acc:HGNC:19699]
# 176 glyceraldehyde-3-phosphate dehydrogenase, spermatogenic [Source:HGNC Symbol;Acc:HGNC:24864]
# 177 S100 calcium binding protein A3 [Source:HGNC Symbol;Acc:HGNC:10493]
# 179 coiled-coil domain containing 39 [Source:HGNC Symbol;Acc:HGNC:25244]
# 180 oxytocin receptor [Source:HGNC Symbol;Acc:HGNC:8529]
# 183 C-C motif chemokine ligand 4 [Source:HGNC Symbol;Acc:HGNC:10630]
# 185 ETS proto-oncogene 1, transcription factor [Source:HGNC Symbol;Acc:HGNC:3488]
# 188 NFKB inhibitor zeta [Source:HGNC Symbol;Acc:HGNC:29805]
# 190 huntingtin associated protein 1 [Source:HGNC Symbol;Acc:HGNC:4812]
# 191 interleukin 1 alpha [Source:HGNC Symbol;Acc:HGNC:5991]
# 193 baculoviral IAP repeat containing 3 [Source:HGNC Symbol;Acc:HGNC:591]
# 194 C-C motif chemokine ligand 5 [Source:HGNC Symbol;Acc:HGNC:10632]
# 196 regulator of G protein signaling 2 [Source:HGNC Symbol;Acc:HGNC:9998]
# 197 NUAK family kinase 2 [Source:HGNC Symbol;Acc:HGNC:29558]
# 199 MBL associated serine protease 2 [Source:HGNC Symbol;Acc:HGNC:6902]
# 201 DnaJ heat shock protein family (Hsp40) member B4 [Source:HGNC Symbol;Acc:HGNC:14886]
# 202 dual specificity phosphatase 2 [Source:HGNC Symbol;Acc:HGNC:3068]
# 203 cytochrome P450 family 1 subfamily B member 1 [Source:HGNC Symbol;Acc:HGNC:2597]

# %%
# Lista de genes que codifican proteínas
genes_codifican_proteinas <- unique(genes_codifican_proteinas$external_gene_name)

# Verificar la presencia de cada gen en genes_codifican_proteinas
genes_presentes <- genes_names %in% genes_codifican_proteinas

# Mostrar los genes que están en genes_codifican_proteinas
genes_encontrados <- genes_names[genes_presentes]
cat("Genes encontrados:\n")
print(genes_encontrados)

# Mostrar los genes que no están en genes_codifican_proteinas
genes_no_encontrados <- genes_names[!genes_presentes]
cat("Genes no encontrados:\n")
print(genes_no_encontrados)
# Out:
# Genes encontrados:
#  [1] "SPG7"     "CITED2"   "MASP2"    "PLK2"     "HSPH1"    "DNAJB4"
#  [7] "SERPINA3" "ADM"      "NCOA7"    "CSF1"     "CSF2"     "CSF3"
# [13] "TICAM1"   "CYP1A1"   "CYP1B1"   "DEDD2"    "RCAN1"    "DUSP2"
# [19] "ETS1"     "DKK1"     "FOXJ1"    "UNC13A"   "FOS"      "FSCN2"
# [25] "L3MBTL1"  "GAPDHS"   "RND1"     "GPM6B"    "CXCL1"    "CXCL2"
# [31] "CXCL3"    "BIRC3"    "HSPA1A"   "HSPA1B"   "HSPA6"    "DNAJB1"
# [37] "ICAM1"    "ID1"      "CCDC39"   "NANOS1"   "NANOS3"   "IL1A"
# [43] "IL1B"     "CXCL8"    "INHBC"    "CXCL10"   "IRF1"     "BNIP5"
# [49] "LIF"      "LTB"      "NFKBIA"   "NPTX1"    "OXTR"     "IL23A"
# [55] "PLAU"     "TOR4A"    "CAMK1G"   "PTAFR"    "RGS2"     "BDKRB2"
# [61] "S100A3"   "CFB"      "SCTR"     "CCL2"     "CCL4"     "CCL5"
# [67] "CCL20"    "CCL22"    "CXCL11"   "CXCL5"    "CX3CL1"   "SDC4"
# [73] "FKBPL"    "NFKBIZ"   "RASL11B"  "SOD2"     "STAT5A"   "THBS1"
# [79] "TNF"      "TNFAIP2"  "TNFAIP3"  "POTEF"    "CHAC1"    "CCDC121"
# [85] "NR4A3"    "NUAK2"    "H3C4"     "TTLL2"    "KRTAP3-1" "SPMIP6"
# [91] "ITPRIP"   "STX11"    "TNFSF14"  "HAP1"     "TMEM88"   "CD83"
# [97] "MAFB"     "HS3ST3B1"
# Genes no encontrados:
#  [1] "EGOT"         "WAKMAR2"      "MIR3189"      "CARD8-AS1"    "STEAP1B-AS1"
#  [6] "MIR4492"      "ARHGAP31-AS1" "MIR8085"      ""             "LINC01767"
# [11] "MIR3142HG"    "SNORD15B"     "SNORD83B"     "LINC02603"    "CYP2T1P"
# [16] "SNORD36C"     "SNORD35A"     "SNORD34"      "SNORD33"      "LINC00641"
# [21] "HLA-L"        "C11orf96"     "MIR17HG"      "C10orf55"     "IL6ST-DT"
# [26] "PDGFA-DT"     "SNORA10"      "SNORD100"     "SNORA41"      "SNORA20"
# [31] "SNORA26"      "SNORA28"      "SNORA29"      "SNORA57"      "MIR616"
# [36] "MIR22HG"      "SNORD14C"     "SNORD14D"     "LIF-AS2"      "SNORD30"

# %%
# Obtener los nombres de las proteínas correspondientes a los genes encontrados
proteinas <- getBM(
  attributes = c("external_gene_name", "uniprotswissprot"),
  filters = "external_gene_name",
  values = genes_encontrados,
  mart = ensembl
)

# Filtrar las filas donde el campo uniprotswissprot no esté vacío
proteinas_filtradas <- proteinas[proteinas$uniprotswissprot != "", ]

# Mostrar los nombres de las proteínas
cat("Nombres de las proteínas correspondientes a los genes encontrados:\n")
print(proteinas_filtradas$uniprotswissprot)
# Out:
# Nombres de las proteínas correspondientes a los genes encontrados:
#  [1] "P15018" "P01100" "O94907" "P31431" "Q01151" "P41134" "Q92598" "O00626"
#  [9] "Q8NI08" "P53805" "Q8IWB1" "P25105" "Q9Y5Q3" "P78423" "P01011" "P13236"
# [17] "Q03169" "Q9BYR8" "P00749" "Q9NXH8" "P13501" "Q9BWV7" "P01584" "Q9BPW5"
# [25] "O43557" "P09919" "Q6PEY1" "P09603" "Q06643" "P05362" "P30411" "P35318"
# [33] "Q9Y662" "P0DMV8" "P0DMV9" "Q9UQ90" "O14926" "P0C671" "P55103" "Q96NX5"
# [41] "P25685" "Q9UIM3" "Q8NCR6" "P60323" "P01375" "Q92949" "Q9Y468" "P47872"
# [49] "P68431" "Q92570" "P19875" "Q8WXF8" "P02778" "O14625" "P78556" "P00751"
# [57] "P04798" "P09341" "P42830" "P19876" "Q9BUX1" "P10145" "P42229" "P17066"
# [65] "Q13491" "P04141" "P25963" "O75558" "P07996" "Q9UPW8" "Q8WY41" "P04179"
# [73] "Q9NPF7" "Q92730" "A5A3E0" "Q8IUC6" "Q15818" "P13500" "Q99967" "P21580"
# [81] "P10914" "Q6ZUS5" "Q9NYY3" "O14556" "P33764" "Q9UFE4" "P30559" "P14921"
# [89] "Q9BYH8" "P54257" "P01583" "Q13489" "P41220" "Q9H093" "O00187" "Q9UDY4"
# [97] "Q05923" "Q16678"

# %%
# Filtrar las filas donde el campo uniprotswissprot no esté vacío
proteinas_filtradas <- proteinas[proteinas$uniprotswissprot != "", ]

# Obtener solo la columna de nombres de proteínas
lista_proteinas <- proteinas_filtradas$uniprotswissprot


# Guardar la lista de proteínas en una variable
lista_proteinas
# Out:
#  [1] "P15018" "P01100" "O94907" "P31431" "Q01151" "P41134" "Q92598" "O00626"
#  [9] "Q8NI08" "P53805" "Q8IWB1" "P25105" "Q9Y5Q3" "P78423" "P01011" "P13236"
# [17] "Q03169" "Q9BYR8" "P00749" "Q9NXH8" "P13501" "Q9BWV7" "P01584" "Q9BPW5"
# [25] "O43557" "P09919" "Q6PEY1" "P09603" "Q06643" "P05362" "P30411" "P35318"
# [33] "Q9Y662" "P0DMV8" "P0DMV9" "Q9UQ90" "O14926" "P0C671" "P55103" "Q96NX5"
# [41] "P25685" "Q9UIM3" "Q8NCR6" "P60323" "P01375" "Q92949" "Q9Y468" "P47872"
# [49] "P68431" "Q92570" "P19875" "Q8WXF8" "P02778" "O14625" "P78556" "P00751"
# [57] "P04798" "P09341" "P42830" "P19876" "Q9BUX1" "P10145" "P42229" "P17066"
# [65] "Q13491" "P04141" "P25963" "O75558" "P07996" "Q9UPW8" "Q8WY41" "P04179"
# [73] "Q9NPF7" "Q92730" "A5A3E0" "Q8IUC6" "Q15818" "P13500" "Q99967" "P21580"
# [81] "P10914" "Q6ZUS5" "Q9NYY3" "O14556" "P33764" "Q9UFE4" "P30559" "P14921"
# [89] "Q9BYH8" "P54257" "P01583" "Q13489" "P41220" "Q9H093" "O00187" "Q9UDY4"
# [97] "Q05923" "Q16678"

# %%
# Asegúrate de que lista_proteinas sea un vector
lista_proteinas_2 <- as.character(lista_proteinas)

# Guardar la lista de proteínas en un archivo CSV sin la columna X y sin comillas
writeLines(lista_proteinas_2, "lista_proteinas_bacillus_subtilis_CW14.csv")

# %%
# Cargar el archivo CSV de nuevo en R
lista_proteinas_cargado <- read.csv("lista_proteinas_bacillus_subtilis_CW14.csv", header = FALSE)

# Renombrar la columna si es necesario
colnames(lista_proteinas_cargado) <- "uniprotswissprot"

# %%
lista_proteinas_cargado
# Out:
#    uniprotswissprot
# 1  P15018
# 2  P01100
# 3  O94907
# 4  P31431
# 5  Q01151
# 6  P41134
# 7  Q92598
# 8  O00626
# 9  Q8NI08
# 10 P53805
# 11 Q8IWB1
# 12 P25105
# 13 Q9Y5Q3
# 14 P78423
# 15 P01011
# 16 P13236
# 17 Q03169
# 18 Q9BYR8
# 19 P00749
# 20 Q9NXH8
# 21 P13501
# 22 Q9BWV7
# 23 P01584
# 24 Q9BPW5
# 25 O43557
# 26 P09919
# 27 Q6PEY1
# 28 P09603
# 29 Q06643
# 30 P05362
# ⋮  ⋮
# 69 P07996
# 70 Q9UPW8
# 71 Q8WY41
# 72 P04179
# 73 Q9NPF7
# 74 Q92730
# 75 A5A3E0
# 76 Q8IUC6
# 77 Q15818
# 78 P13500
# 79 Q99967
# 80 P21580
# 81 P10914
# 82 Q6ZUS5
# 83 Q9NYY3
# 84 O14556
# 85 P33764
# 86 Q9UFE4
# 87 P30559
# 88 P14921
# 89 Q9BYH8
# 90 P54257
# 91 P01583
# 92 Q13489
# 93 P41220
# 94 Q9H093
# 95 O00187
# 96 Q9UDY4
# 97 Q05923
# 98 Q16678
