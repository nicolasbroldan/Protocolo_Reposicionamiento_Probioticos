# %%
if (!require("BiocManager", quietly = TRUE))
  install.packages("BiocManager")
BiocManager::install

# %%
BiocManager::install("biomaRt")
library(biomaRt)

# %%
library(BiocManager)
BiocManager::install('GOstats')
BiocManager::install("clusterProfiler")
BiocManager::install("org.Hs.eg.db")
BiocManager::install("enrichplot")
#BiocManager::install("Rtools")

# %%
# Leer el archivo CSV
data <- read.csv("deSeqRes_filtrado_Fusobacterium_Nucleatum.csv")
# Filtrar los genes significativos
genes_significativos <- subset(data, padj < 0.05)
# Extraer la lista de genes significativos
lista_genes <- genes_significativos$gene_name
# Verificar si los genes son números (posiblemente IDs de Entrez)
if (all(grepl("^\\d+$", lista_genes))) {
    genes_ids <- lista_genes
} else {
    # Convertir los nombres de genes a IDs de Entrez si son símbolos
    genes_ids <- bitr(lista_genes, fromType = "SYMBOL", toType = "ENTREZID", OrgDb = org.Hs.eg.db)$ENTREZID
}
genes_ids
# Out:
#   [1]      3398      1490     23193    140766      4092      5099      7057
#   [8]     84836    389136      4804      5142    399959      9498     57613
#  [15]      8848      4929     51421       221      3860      7171      9957
#  [22]     22927       760    131583 100287569       631     56993     63967
#  [29]     55789     57552     79991     10769     22836    157570    730755
#  [36] 105375503     27113    374946 106635533    126731      4277     51384
#  [43]      9221    114794     27074    219790     80854      2736      6623
#  [50]     25984       840     26472      7077    285362    286467      6272
#  [57]    221710      9965      4254 100532742     57402     79801    649446
#  [64]      4199      3909      3783      6653     80315    117854      5155
#  [71]      3977     28962      3014     50515     51200      1244      4603
#  [78]     57405      3673      4493       595     84263     51703     57761
#  [85]     84632     26298    170261    113622      8544 100008588     55245
#  [92]      8507      5414     55796     22979      4758     91947     23568
#  [99]     90317      8751      8506      6674     11098       770    283554
# [106]      7023 100128338    135398      2272     10553    221662      5087
# [113]      5027     10855      5243 100288866      9183 109864273 107986178
# [120]     90427 106631781      1062     11339 100507053 105369634      6817
# [127]      7483      8534      6498     11054 105372860 105371441 105370503
# [134]    116931      9628     10389     51083 105371692     10788     81575
# [141]     57476      2022      9582     80022    144455    222171     84878
# [148]     51702    728279      8850 101928034     10882      1591     55879
# [155]     11151      5698 102723566 100272228     26047     83786      2861
# [162]      9120 105372862     55214 102724009     57088     10580     80139
# [169] 100233156      1290      8631     58480 105373424      1303    374393
# [176] 100505385     29970      4558        59    414149      4091      7857
# [183]      3382    735301     11013     23401      5002      4567    115111
# [190]     79413     84223     10333 109910380     26018      1509    127343
# [197]      4900      8204     10472    401320      4577     10457    161176
# [204] 100507217     92249     54494       933 109864280      7052    196996
# [211]    150967      6591     85294 100874530 105373886     79922     58985
# [218]        15      8321     55170    643401      8744      3670     57121
# [225]     11178 100996579 101928483    204010     83988     84541    407975
# [232]     90024 107984500     55061     10736     56971    139818    400499
# [239]    145173    147645     84964    144132      2872 105372578    253264
# [246] 108570035    119395      8529      2838 105373888      3373    203259
# [253]    400224     23179     80312    170689     66008

# %%
library(biomaRt)
library(org.Hs.eg.db)
# Convertir los IDs de Entrez a nombres de genes si son IDs de Entrez
if (all(grepl("^\\d+$", genes_ids))) {
    # Crear una conexión a la base de datos de biomart
    mart <- useMart(biomart = "ensembl", dataset = "hsapiens_gene_ensembl")
    
    # Obtener los nombres de los genes correspondientes a los IDs de Entrez
    gene_info <- getBM(attributes = c("entrezgene_id", "external_gene_name"), 
                       filters = "entrezgene_id", 
                       values = genes_ids, 
                       mart = mart)
    
    # Reemplazar los IDs de Entrez por los nombres de los genes convertidos
    genes_names <- gene_info$external_gene_name
}

# %%
genes_names
# Out:
#   [1] "TEKT4P2"      "LINC00173"    "NGFR-AS1"     "IQCJ-SCHIP1"  ""
#   [6] "APOBEC3B-AS1" "LINC01806"    ""             "KIF1C-AS1"    "TLR6"
#  [11] "SCML2"        "GPNMB"        "ZBTB18"       "LINC02331"    "HTATIP2"
#  [16] "SORBS1"       "CENPE"        "SIX2"         "PLK2"         "IQGAP2"
#  [21] ""             "HPSE"         "C1QL1"        "TMSB15A"      "OGFR"
#  [26] "PRSS23"       "CORO1A"       "LZTS1"        "OIP5"         "ADPRHL1"
#  [31] "ELFN2"        "SLC26A7"      "MED12L"       "TRIM6"        "CALHM3"
#  [36] "ABCC2"        "CCSAP"        "DMBX1"        "COL5A2"       "COL12A1"
#  [41] "FAM43A"       "C6orf141"     "DOCK11"       "ADAMTS14"     "DNHD1"
#  [46] "E2F7"         "B3GLCT"       "VSIG10L"      "CCN2"         "AANAT"
#  [51] "CTSD"         "LINC01963"    "ESCO2"        "CYP24A1"      "SYNE3"
#  [56] "ZCCHC12"      "ADAMTS15"     "GRAMD2A"      "ENG"          "FAM219A"
#  [61] "RPSAP52"      "RTKN2"        "ALDH3B1"      "RBM24"        "SMIM13"
#  [66] "PRR15"        "FHIT"         "RHOBTB3"      "HABP4"        "EFR3B"
#  [71] "RGL1"         "GANAB"        "FRAT2"        "ARL2BP"       "ZNF503-AS1"
#  [76] "KRT23"        "LRIG1"        "CNTNAP2"      "EHF"          "PPP1R14B"
#  [81] "LAMP3"        "BBC3"         "GLI2"         "GPR137C"      "GPR15"
#  [86] "SUMF1"        "GPR37"        "FIRRE"        "MKNK2"        "OSTM1"
#  [91] "SCHIP1"       "H2AX"         "HYAL1"        "ICA1"         "ID2"
#  [96] "ISL1"         "ITGA2"        "FAM111B"      "DRAXIN"       "KCNN4"
# [101] "KRT13"        "VGLL3"        "LAMA3"        "LIFR"         "MIR100HG"
# [106] "PLEKHD1"      ""             "MIR17HG"      "SMAD6"        "SMAD7"
# [111] "ACBD7"        "ME1"          "KITLG"        "MICB"         "MT1E"
# [116] "MYBL1"        "NEU1"         "NGFR"         "NRGN"         "NR4A2"
# [121] "SLC22A18"     "P2RX7"        "CHST11"       "PBX1"         "PCDH7"
# [126] "GAL"          "CPA4"         "WNT16"        "PDE4B"        "AMOTL2"
# [131] "PDGFB"        "PADI3"        "ACSL5"        "ABCB1"        "SEPTIN4"
# [136] "C11orf71"     "SUSD4"        "PRMT6"        "P3H2"         "UQCC1"
# [141] "DEPDC1B"      "MBNL3"        "GABRQ"        "CEACAM19"     "PSMB9"
# [146] "TOMM22"       "PLSCR4"       "LPAR5"        "S100A14"      "SPC25"
# [151] "GRAMD1B"      "NCEH1"        "FAM234B"      "TRIB3"        "RHOU"
# [156] "IL22RA1"      "ACTA2"        "CCND1"        "SORT1"        "BFSP1"
# [161] "CLSPN"        "PURPL"        "SKIL"         "SNAI2"        "TRAK2"
# [166] "SNCG"         "SORL1"        "SPAG1"        ""             "SULT1A1"
# [171] "TFAP4"        "TGM2"         "THBS1"        "TIMP2"        "TPM4"
# [176] "KRTAP2-2"     ""             "KRTAP2-3"     "WNT9A"        "CA2"
# [181] "CA11"         "SCG2"         "ZBED2"        "SHCBP1"       "MRM1"
# [186] "STN1"         "MYO15B"       "ZNF703"       "TET1"         "CPEB4"
# [191] "SETD7"        "APOLD1"       "NRIP1"        "FZD1"         "FRMD8"
# [196] "NCALD"        "CASP7"        "IQCG"         "HSDL2"        "KBTBD8"
# [201] "AFAP1L2"      "ABHD14B"      "ZBTB45"       "ALKBH6"       "CNTNAP1"
# [206] "ENC1"         "CYP4F2"       "KRTAP2-4"     "CHST1"        "PIR"
# [211] "SKAP1"        "TNFSF9"       "ADAM15"       "TSC22D1"      "KAT2B"
# [216] "FLJ20021"     "ZNF616"       "BMF"          "SLC16A6"      "ZW10"
# [221] "ARRDC4"       "NOLC1"        "LINC01278"    "CD22"         "SLC4A8"
# [226] "APOBEC3B"     "RGS6"         "HS3ST1"       "FGF19"

# %%
# Conectarse a la base de datos UniProt usando el conjunto de datos 'hsapiens_gene_ensembl'
ensembl <- useMart("ensembl", dataset = "hsapiens_gene_ensembl")

# %%
# Obtener la información de las proteínas correspondientes a los nombres de los genes
info_proteinas <- getBM(attributes = c("ensembl_gene_id", "external_gene_name", "uniprotswissprot", "description"),
                        filters = "external_gene_name",
                        values = genes_names,
                        mart = mart)

# %%
# Filtrar para obtener solo los genes que codifican proteínas
genes_codifican_proteinas <- info_proteinas[info_proteinas$uniprotswissprot != "", ]

# Mostrar los resultados
genes_codifican_proteinas
# Out:
#     ensembl_gene_id external_gene_name uniprotswissprot
# 1   ENSG00000125864 BFSP1              Q12934
# 2   ENSG00000100311 PDGFB              P01127
# 4   ENSG00000284984 RHOU               Q7L0Q8
# 5   ENSG00000280549 PADI3              Q9ULW8
# 6   ENSG00000180998 GPR137C            Q8N3F9
# 8   ENSG00000104081 BMF                Q96LC9
# 10  ENSG00000179750 APOBEC3B           Q9UH17
# 12  ENSG00000176244 ACBD7              Q8N6N7
# 13  ENSG00000102098 SCML2              Q9UQR0
# 15  ENSG00000175985 PLEKHD1            A6NEE1
# 16  ENSG00000137834 SMAD6              O43541
# 18  ENSG00000087842 PIR                O00625
# 19  ENSG00000003147 ICA1               Q05084
# 21  ENSG00000002587 HS3ST1             O14792
# 23  ENSG00000182732 RGS6               P49758
# 26  ENSG00000153531 ADPRHL1            Q8NDY3
# 27  ENSG00000112183 RBM24              Q9BX46
# 29  ENSG00000114166 KAT2B              Q92831
# 30  ENSG00000065833 ME1                P48163
# 31  ENSG00000187676 B3GLCT             Q6Y288
# 32  ENSG00000104267 CA2                P00918
# 34  ENSG00000119471 HSDL2              Q6YN16
# 36  ENSG00000144455 SUMF1              Q8NBK3
# 38  ENSG00000053747 LAMA3              Q16787
# 40  ENSG00000180530 NRIP1              P48552
# 42  ENSG00000114378 HYAL1              Q12794
# 44  ENSG00000186115 CYP4F2             P78329
# 46  ENSG00000181274 FRAT2              O75474
# 47  ENSG00000100216 TOMM22             Q9NS69
# 48  ENSG00000084710 EFR3B              Q9Y2G0
# ⋮   ⋮               ⋮                  ⋮
# 359 ENSG00000142677 IL22RA1            Q8N6P7
# 361 ENSG00000104783 KCNN4              O15554
# 362 ENSG00000143537 ADAM15             Q13444
# 363 ENSG00000154146 NRGN               Q92686
# 365 ENSG00000145703 IQGAP2             Q13576
# 368 ENSG00000150687 PRSS23             O95084
# 369 ENSG00000136603 SKIL               P12757
# 372 ENSG00000035862 TIMP2              P16035
# 373 ENSG00000078081 LAMP3              Q9UQV4
# 375 ENSG00000064300 NGFR               P08138
# 377 ENSG00000189283 FHIT               P49789
# 379 ENSG00000184588 PDE4B              Q07343
# 381 ENSG00000177494 ZBED2              Q9BTP6
# 382 ENSG00000137642 SORL1              Q92673
# 385 ENSG00000164292 RHOBTB3            O94955
# 386 ENSG00000134243 SORT1              Q99523
# 388 ENSG00000171951 SCG2               P13521
# 390 ENSG00000171617 ENC1               O14682
# 392 ENSG00000153234 NR4A2              P43354
# 394 ENSG00000154165 GPR15              P49685
# 395 ENSG00000035499 DEPDC1B            Q8WUY9
# 398 ENSG00000283154 IQCJ-SCHIP1        B3KU38
# 400 ENSG00000151967 SCHIP1             P0DPB3
# 401 ENSG00000162490 DRAXIN             Q8NBI3
# 403 ENSG00000179456 ZBTB18             Q99592
# 404 ENSG00000143816 WNT9A              O14904
# 405 ENSG00000185630 PBX1               P40424
# 407 ENSG00000170577 SIX2               Q9NPC8
# 408 ENSG00000204262 COL5A2             P05997
# 410 ENSG00000197587 DMBX1              Q8NFW5
#     description
# 1   beaded filament structural protein 1 [Source:HGNC Symbol;Acc:HGNC:1040]
# 2   platelet derived growth factor subunit B [Source:HGNC Symbol;Acc:HGNC:8800]
# 4   ras homolog family member U [Source:HGNC Symbol;Acc:HGNC:17794]
# 5   peptidyl arginine deiminase 3 [Source:HGNC Symbol;Acc:HGNC:18337]
# 6   G protein-coupled receptor 137C [Source:HGNC Symbol;Acc:HGNC:25445]
# 8   Bcl2 modifying factor [Source:HGNC Symbol;Acc:HGNC:24132]
# 10  apolipoprotein B mRNA editing enzyme catalytic subunit 3B [Source:HGNC Symbol;Acc:HGNC:17352]
# 12  acyl-CoA binding domain containing 7 [Source:HGNC Symbol;Acc:HGNC:17715]
# 13  Scm polycomb group protein like 2 [Source:HGNC Symbol;Acc:HGNC:10581]
# 15  pleckstrin homology and coiled-coil domain containing D1 [Source:HGNC Symbol;Acc:HGNC:20148]
# 16  SMAD family member 6 [Source:HGNC Symbol;Acc:HGNC:6772]
# 18  pirin [Source:HGNC Symbol;Acc:HGNC:30048]
# 19  islet cell autoantigen 1 [Source:HGNC Symbol;Acc:HGNC:5343]
# 21  heparan sulfate-glucosamine 3-sulfotransferase 1 [Source:HGNC Symbol;Acc:HGNC:5194]
# 23  regulator of G protein signaling 6 [Source:HGNC Symbol;Acc:HGNC:10002]
# 26  ADP-ribosylhydrolase like 1 [Source:HGNC Symbol;Acc:HGNC:21303]
# 27  RNA binding motif protein 24 [Source:HGNC Symbol;Acc:HGNC:21539]
# 29  lysine acetyltransferase 2B [Source:HGNC Symbol;Acc:HGNC:8638]
# 30  malic enzyme 1 [Source:HGNC Symbol;Acc:HGNC:6983]
# 31  beta 3-glucosyltransferase [Source:HGNC Symbol;Acc:HGNC:20207]
# 32  carbonic anhydrase 2 [Source:HGNC Symbol;Acc:HGNC:1373]
# 34  hydroxysteroid dehydrogenase like 2 [Source:HGNC Symbol;Acc:HGNC:18572]
# 36  sulfatase modifying factor 1 [Source:HGNC Symbol;Acc:HGNC:20376]
# 38  laminin subunit alpha 3 [Source:HGNC Symbol;Acc:HGNC:6483]
# 40  nuclear receptor interacting protein 1 [Source:HGNC Symbol;Acc:HGNC:8001]
# 42  hyaluronidase 1 [Source:HGNC Symbol;Acc:HGNC:5320]
# 44  cytochrome P450 family 4 subfamily F member 2 [Source:HGNC Symbol;Acc:HGNC:2645]
# 46  FRAT regulator of WNT signaling pathway 2 [Source:HGNC Symbol;Acc:HGNC:16048]
# 47  translocase of outer mitochondrial membrane 22 [Source:HGNC Symbol;Acc:HGNC:18002]
# 48  EFR3 homolog B [Source:HGNC Symbol;Acc:HGNC:29155]
# ⋮   ⋮
# 359 interleukin 22 receptor subunit alpha 1 [Source:HGNC Symbol;Acc:HGNC:13700]
# 361 potassium calcium-activated channel subfamily N member 4 [Source:HGNC Symbol;Acc:HGNC:6293]
# 362 ADAM metallopeptidase domain 15 [Source:HGNC Symbol;Acc:HGNC:193]
# 363 neurogranin [Source:HGNC Symbol;Acc:HGNC:8000]
# 365 IQ motif containing GTPase activating protein 2 [Source:HGNC Symbol;Acc:HGNC:6111]
# 368 serine protease 23 [Source:HGNC Symbol;Acc:HGNC:14370]
# 369 SKI like proto-oncogene [Source:HGNC Symbol;Acc:HGNC:10897]
# 372 TIMP metallopeptidase inhibitor 2 [Source:HGNC Symbol;Acc:HGNC:11821]
# 373 lysosomal associated membrane protein 3 [Source:HGNC Symbol;Acc:HGNC:14582]
# 375 nerve growth factor receptor [Source:HGNC Symbol;Acc:HGNC:7809]
# 377 fragile histidine triad diadenosine triphosphatase [Source:HGNC Symbol;Acc:HGNC:3701]
# 379 phosphodiesterase 4B [Source:HGNC Symbol;Acc:HGNC:8781]
# 381 zinc finger BED-type containing 2 [Source:HGNC Symbol;Acc:HGNC:20710]
# 382 sortilin related receptor 1 [Source:HGNC Symbol;Acc:HGNC:11185]
# 385 Rho related BTB domain containing 3 [Source:HGNC Symbol;Acc:HGNC:18757]
# 386 sortilin 1 [Source:HGNC Symbol;Acc:HGNC:11186]
# 388 secretogranin II [Source:HGNC Symbol;Acc:HGNC:10575]
# 390 ectodermal-neural cortex 1 [Source:HGNC Symbol;Acc:HGNC:3345]
# 392 nuclear receptor subfamily 4 group A member 2 [Source:HGNC Symbol;Acc:HGNC:7981]
# 394 G protein-coupled receptor 15 [Source:HGNC Symbol;Acc:HGNC:4469]
# 395 DEP domain containing 1B [Source:HGNC Symbol;Acc:HGNC:24902]
# 398 IQCJ-SCHIP1 readthrough [Source:HGNC Symbol;Acc:HGNC:38842]
# 400 schwannomin interacting protein 1 [Source:HGNC Symbol;Acc:HGNC:15678]
# 401 dorsal inhibitory axon guidance protein [Source:HGNC Symbol;Acc:HGNC:25054]
# 403 zinc finger and BTB domain containing 18 [Source:HGNC Symbol;Acc:HGNC:13030]
# 404 Wnt family member 9A [Source:HGNC Symbol;Acc:HGNC:12778]
# 405 PBX homeobox 1 [Source:HGNC Symbol;Acc:HGNC:8632]
# 407 SIX homeobox 2 [Source:HGNC Symbol;Acc:HGNC:10888]
# 408 collagen type V alpha 2 chain [Source:HGNC Symbol;Acc:HGNC:2210]
# 410 diencephalon/mesencephalon homeobox 1 [Source:HGNC Symbol;Acc:HGNC:19026]

# %%
# Lista de genes que codifican proteínas
genes_codifican_proteinas <- unique(genes_codifican_proteinas$external_gene_name)

# Verificar la presencia de cada gen en genes_codifican_proteinas
genes_presentes <- genes_names %in% genes_codifican_proteinas

# Mostrar los genes que están en genes_codifican_proteinas
genes_encontrados <- genes_names[genes_presentes]
cat("Genes encontrados:\n")
print(genes_encontrados)

# Mostrar los genes que no están en genes_codifican_proteinas
genes_no_encontrados <- genes_names[!genes_presentes]
cat("Genes no encontrados:\n")
print(genes_no_encontrados)
# Out:
# Genes encontrados:
#   [1] "IQCJ-SCHIP1" "TLR6"        "SCML2"       "GPNMB"       "ZBTB18"
#   [6] "HTATIP2"     "SORBS1"      "CENPE"       "SIX2"        "PLK2"
#  [11] "IQGAP2"      "HPSE"        "C1QL1"       "TMSB15A"     "OGFR"
#  [16] "PRSS23"      "CORO1A"      "LZTS1"       "OIP5"        "ADPRHL1"
#  [21] "ELFN2"       "SLC26A7"     "MED12L"      "TRIM6"       "CALHM3"
#  [26] "ABCC2"       "CCSAP"       "DMBX1"       "COL5A2"      "COL12A1"
#  [31] "FAM43A"      "C6orf141"    "DOCK11"      "ADAMTS14"    "DNHD1"
#  [36] "E2F7"        "B3GLCT"      "VSIG10L"     "CCN2"        "AANAT"
#  [41] "CTSD"        "ESCO2"       "CYP24A1"     "SYNE3"       "ZCCHC12"
#  [46] "ADAMTS15"    "GRAMD2A"     "ENG"         "FAM219A"     "RTKN2"
#  [51] "ALDH3B1"     "RBM24"       "SMIM13"      "PRR15"       "FHIT"
#  [56] "RHOBTB3"     "HABP4"       "EFR3B"       "RGL1"        "GANAB"
#  [61] "FRAT2"       "ARL2BP"      "KRT23"       "LRIG1"       "CNTNAP2"
#  [66] "EHF"         "PPP1R14B"    "LAMP3"       "BBC3"        "GLI2"
#  [71] "GPR137C"     "GPR15"       "SUMF1"       "GPR37"       "MKNK2"
#  [76] "OSTM1"       "SCHIP1"      "H2AX"        "HYAL1"       "ICA1"
#  [81] "ID2"         "ISL1"        "ITGA2"       "FAM111B"     "DRAXIN"
#  [86] "KCNN4"       "KRT13"       "VGLL3"       "LAMA3"       "LIFR"
#  [91] "PLEKHD1"     "SMAD6"       "SMAD7"       "ACBD7"       "ME1"
#  [96] "KITLG"       "MICB"        "MT1E"        "MYBL1"       "NEU1"
# [101] "NGFR"        "NRGN"        "NR4A2"       "SLC22A18"    "P2RX7"
# [106] "CHST11"      "PBX1"        "PCDH7"       "GAL"         "CPA4"
# [111] "WNT16"       "PDE4B"       "AMOTL2"      "PDGFB"       "PADI3"
# [116] "ACSL5"       "ABCB1"       "SEPTIN4"     "C11orf71"    "SUSD4"
# [121] "PRMT6"       "P3H2"        "UQCC1"       "DEPDC1B"     "MBNL3"
# [126] "GABRQ"       "CEACAM19"    "PSMB9"       "TOMM22"      "PLSCR4"
# [131] "LPAR5"       "S100A14"     "SPC25"       "GRAMD1B"     "NCEH1"
# [136] "FAM234B"     "TRIB3"       "RHOU"        "IL22RA1"     "ACTA2"
# [141] "CCND1"       "SORT1"       "BFSP1"       "CLSPN"       "SKIL"
# [146] "SNAI2"       "TRAK2"       "SNCG"        "SORL1"       "SPAG1"
# [151] "SULT1A1"     "TFAP4"       "TGM2"        "THBS1"       "TIMP2"
# [156] "TPM4"        "KRTAP2-2"    "KRTAP2-3"    "WNT9A"       "CA2"
# [161] "CA11"        "SCG2"        "ZBED2"       "SHCBP1"      "MRM1"
# [166] "STN1"        "ZNF703"      "TET1"        "CPEB4"       "SETD7"
# [171] "APOLD1"      "NRIP1"       "FZD1"        "FRMD8"       "NCALD"
# [176] "CASP7"       "IQCG"        "HSDL2"       "KBTBD8"      "AFAP1L2"
# [181] "ABHD14B"     "ZBTB45"      "ALKBH6"      "CNTNAP1"     "ENC1"
# [186] "CYP4F2"      "KRTAP2-4"    "CHST1"       "PIR"         "SKAP1"
# [191] "TNFSF9"      "ADAM15"      "TSC22D1"     "KAT2B"       "ZNF616"
# [196] "BMF"         "SLC16A6"     "ZW10"        "ARRDC4"      "NOLC1"
# [201] "CD22"        "SLC4A8"      "APOBEC3B"    "RGS6"        "HS3ST1"
# [206] "FGF19"
# Genes no encontrados:
#  [1] "TEKT4P2"      "LINC00173"    "NGFR-AS1"     ""             "APOBEC3B-AS1"
#  [6] "LINC01806"    ""             "KIF1C-AS1"    "LINC02331"    ""
# [11] "LINC01963"    "RPSAP52"      "ZNF503-AS1"   "FIRRE"        "MIR100HG"
# [16] ""             "MIR17HG"      "PURPL"        ""             ""
# [21] "MYO15B"       "FLJ20021"     "LINC01278"

# %%
# Obtener los nombres de las proteínas correspondientes a los genes encontrados
proteinas <- getBM(
  attributes = c("external_gene_name", "uniprotswissprot"),
  filters = "external_gene_name",
  values = genes_encontrados,
  mart = ensembl
)

# Filtrar las filas donde el campo uniprotswissprot no esté vacío
proteinas_filtradas <- proteinas[proteinas$uniprotswissprot != "", ]

# Mostrar los nombres de las proteínas
cat("Nombres de las proteínas correspondientes a los genes encontrados:\n")
print(proteinas_filtradas$uniprotswissprot)
# Out:
# Nombres de las proteínas correspondientes a los genes encontrados:
#   [1] "Q12934" "P01127" "Q7L0Q8" "Q9ULW8" "Q8N3F9" "Q96LC9" "Q9UH17" "Q8N6N7"
#   [9] "Q9UQR0" "A6NEE1" "O43541" "O00625" "Q05084" "O14792" "P49758" "Q8NDY3"
#  [17] "Q9BX46" "Q92831" "P48163" "Q6Y288" "P00918" "Q6YN16" "Q8NBK3" "Q16787"
#  [25] "P48552" "Q12794" "P78329" "O75474" "Q9NS69" "Q9Y2G0" "A8MV65" "O43623"
#  [33] "Q15714" "Q8NFY9" "P61601" "Q9NZT2" "O15105" "Q9HAW4" "P22466" "Q01664"
#  [41] "Q9NPF2" "Q2Y0W8" "Q8IZC4" "Q9C075" "P0C7H8" "Q9BYR9" "P0CG34" "P0DX04"
#  [49] "P04732" "Q6IN84" "Q86WV1" "Q07617" "P20273" "Q96C90" "P41273" "Q14978"
#  [57] "Q9C030" "P21583" "Q6SJ93" "Q5R3F8" "Q9UBV4" "Q5JSL3" "Q96AV8" "O15354"
#  [65] "Q9HBM1" "Q14956" "Q8IVL5" "Q29980" "Q96BI1" "Q07973" "O76070" "Q9UI42"
#  [73] "Q9ULC5" "Q9UHC6" "O43482" "O75973" "Q6PIU2" "Q9UN88" "Q99519" "Q8WXS8"
#  [81] "Q86XJ0" "Q99572" "O75493" "P28065" "Q9UP38" "Q16613" "Q9NZC4" "Q8IUY3"
#  [89] "P08183" "Q9Y2Y0" "Q6ZMZ3" "Q8N2R8" "P10243" "Q8IW50" "Q9Y251" "Q99715"
#  [97] "Q96JA1" "P07339" "P55210" "Q9NVA1" "Q9BUP3" "Q8WTS6" "Q6IPW1" "P29279"
# [105] "Q9NUK0" "P10070" "Q9NRQ2" "Q8N4X5" "Q9H1C0" "P21980" "Q9H668" "Q96RU7"
# [113] "Q02224" "P61371" "P78357" "Q8TE54" "Q9Y2J4" "Q9HBH9" "Q9H7S9" "Q9Y2C9"
# [121] "Q14697" "P17301" "Q56NI9" "Q5SZD1" "Q6PEW1" "O60245" "Q86VR7" "Q9NZL6"
# [129] "Q96LA8" "Q96IU4" "Q8IV56" "Q5JVS0" "O43236" "Q9BX66" "Q86WC4" "Q8TE58"
# [137] "P42702" "Q92887" "Q9Y250" "P07996" "P31146" "P13646" "Q17RY0" "Q3KRA9"
# [145] "P0DJ93" "Q8NFU7" "P17813" "O60296" "P62736" "O15403" "Q3KR37" "Q96LR9"
# [153] "Q8NCT1" "P16104" "Q5VX71" "Q86YW9" "P24385" "O95750" "Q9BXH1" "Q96PG8"
# [161] "Q8NEM2" "Q08AN1" "Q02363" "Q6IQ19" "Q96K62" "Q9H095" "Q9BYT5" "P67936"
# [169] "P50225" "Q9NYY3" "Q96M86" "Q7Z692" "O43264" "O43916" "Q9BZ67" "P43353"
# [177] "Q9HCY8" "A2RU67" "Q8N6P7" "O15554" "Q13444" "Q92686" "Q13576" "O95084"
# [185] "P12757" "P16035" "Q9UQV4" "P08138" "P49789" "Q07343" "Q9BTP6" "Q92673"
# [193] "O94955" "Q99523" "P13521" "O14682" "P43354" "P49685" "Q8WUY9" "B3KU38"
# [201] "P0DPB3" "Q8NBI3" "Q99592" "O14904" "P40424" "Q9NPC8" "P05997" "Q8NFW5"

# %%
# Filtrar las filas donde el campo uniprotswissprot no esté vacío
proteinas_filtradas <- proteinas[proteinas$uniprotswissprot != "", ]

# Obtener solo la columna de nombres de proteínas
lista_proteinas <- proteinas_filtradas$uniprotswissprot


# Guardar la lista de proteínas en una variable
lista_proteinas
# Out:
#   [1] "Q12934" "P01127" "Q7L0Q8" "Q9ULW8" "Q8N3F9" "Q96LC9" "Q9UH17" "Q8N6N7"
#   [9] "Q9UQR0" "A6NEE1" "O43541" "O00625" "Q05084" "O14792" "P49758" "Q8NDY3"
#  [17] "Q9BX46" "Q92831" "P48163" "Q6Y288" "P00918" "Q6YN16" "Q8NBK3" "Q16787"
#  [25] "P48552" "Q12794" "P78329" "O75474" "Q9NS69" "Q9Y2G0" "A8MV65" "O43623"
#  [33] "Q15714" "Q8NFY9" "P61601" "Q9NZT2" "O15105" "Q9HAW4" "P22466" "Q01664"
#  [41] "Q9NPF2" "Q2Y0W8" "Q8IZC4" "Q9C075" "P0C7H8" "Q9BYR9" "P0CG34" "P0DX04"
#  [49] "P04732" "Q6IN84" "Q86WV1" "Q07617" "P20273" "Q96C90" "P41273" "Q14978"
#  [57] "Q9C030" "P21583" "Q6SJ93" "Q5R3F8" "Q9UBV4" "Q5JSL3" "Q96AV8" "O15354"
#  [65] "Q9HBM1" "Q14956" "Q8IVL5" "Q29980" "Q96BI1" "Q07973" "O76070" "Q9UI42"
#  [73] "Q9ULC5" "Q9UHC6" "O43482" "O75973" "Q6PIU2" "Q9UN88" "Q99519" "Q8WXS8"
#  [81] "Q86XJ0" "Q99572" "O75493" "P28065" "Q9UP38" "Q16613" "Q9NZC4" "Q8IUY3"
#  [89] "P08183" "Q9Y2Y0" "Q6ZMZ3" "Q8N2R8" "P10243" "Q8IW50" "Q9Y251" "Q99715"
#  [97] "Q96JA1" "P07339" "P55210" "Q9NVA1" "Q9BUP3" "Q8WTS6" "Q6IPW1" "P29279"
# [105] "Q9NUK0" "P10070" "Q9NRQ2" "Q8N4X5" "Q9H1C0" "P21980" "Q9H668" "Q96RU7"
# [113] "Q02224" "P61371" "P78357" "Q8TE54" "Q9Y2J4" "Q9HBH9" "Q9H7S9" "Q9Y2C9"
# [121] "Q14697" "P17301" "Q56NI9" "Q5SZD1" "Q6PEW1" "O60245" "Q86VR7" "Q9NZL6"
# [129] "Q96LA8" "Q96IU4" "Q8IV56" "Q5JVS0" "O43236" "Q9BX66" "Q86WC4" "Q8TE58"
# [137] "P42702" "Q92887" "Q9Y250" "P07996" "P31146" "P13646" "Q17RY0" "Q3KRA9"
# [145] "P0DJ93" "Q8NFU7" "P17813" "O60296" "P62736" "O15403" "Q3KR37" "Q96LR9"
# [153] "Q8NCT1" "P16104" "Q5VX71" "Q86YW9" "P24385" "O95750" "Q9BXH1" "Q96PG8"
# [161] "Q8NEM2" "Q08AN1" "Q02363" "Q6IQ19" "Q96K62" "Q9H095" "Q9BYT5" "P67936"
# [169] "P50225" "Q9NYY3" "Q96M86" "Q7Z692" "O43264" "O43916" "Q9BZ67" "P43353"
# [177] "Q9HCY8" "A2RU67" "Q8N6P7" "O15554" "Q13444" "Q92686" "Q13576" "O95084"
# [185] "P12757" "P16035" "Q9UQV4" "P08138" "P49789" "Q07343" "Q9BTP6" "Q92673"
# [193] "O94955" "Q99523" "P13521" "O14682" "P43354" "P49685" "Q8WUY9" "B3KU38"
# [201] "P0DPB3" "Q8NBI3" "Q99592" "O14904" "P40424" "Q9NPC8" "P05997" "Q8NFW5"

# %%
# Asegúrate de que lista_proteinas sea un vector
lista_proteinas_2 <- as.character(lista_proteinas)

# Guardar la lista de proteínas en un archivo CSV sin la columna X y sin comillas
writeLines(lista_proteinas_2, "lista_proteinas_Fusobacterium_Nucleatum.csv")

# %%
# Cargar el archivo CSV de nuevo en R
lista_proteinas_cargado <- read.csv("lista_proteinas_Fusobacterium_Nucleatum.csv", header = FALSE)

# Renombrar la columna si es necesario
colnames(lista_proteinas_cargado) <- "uniprotswissprot"

# %%
lista_proteinas_cargado
# Out:
#     uniprotswissprot
# 1   Q12934
# 2   P01127
# 3   Q7L0Q8
# 4   Q9ULW8
# 5   Q8N3F9
# 6   Q96LC9
# 7   Q9UH17
# 8   Q8N6N7
# 9   Q9UQR0
# 10  A6NEE1
# 11  O43541
# 12  O00625
# 13  Q05084
# 14  O14792
# 15  P49758
# 16  Q8NDY3
# 17  Q9BX46
# 18  Q92831
# 19  P48163
# 20  Q6Y288
# 21  P00918
# 22  Q6YN16
# 23  Q8NBK3
# 24  Q16787
# 25  P48552
# 26  Q12794
# 27  P78329
# 28  O75474
# 29  Q9NS69
# 30  Q9Y2G0
# ⋮   ⋮
# 179 Q8N6P7
# 180 O15554
# 181 Q13444
# 182 Q92686
# 183 Q13576
# 184 O95084
# 185 P12757
# 186 P16035
# 187 Q9UQV4
# 188 P08138
# 189 P49789
# 190 Q07343
# 191 Q9BTP6
# 192 Q92673
# 193 O94955
# 194 Q99523
# 195 P13521
# 196 O14682
# 197 P43354
# 198 P49685
# 199 Q8WUY9
# 200 B3KU38
# 201 P0DPB3
# 202 Q8NBI3
# 203 Q99592
# 204 O14904
# 205 P40424
# 206 Q9NPC8
# 207 P05997
# 208 Q8NFW5

# %%
# Cargar las librerías necesarias
library(org.Hs.eg.db)
library(dplyr)

# Leer el archivo CSV
data <- read.csv("deSeqRes_filtrado_Fusobacterium_Nucleatum.csv")

# Filtrar los genes significativos (padj < 0.05) y asegurarse de que los nombres de genes estén como caracteres
genes_significativos <- data %>% 
  filter(padj < 0.05) %>%
  mutate(gene_name = as.character(gene_name))

# Verificar si los genes son IDs de Entrez o símbolos, y convertir a EntrezID si es necesario
genes_ids <- if (all(grepl("^\\d+$", genes_significativos$gene_name))) {
  genes_significativos$gene_name
} else {
  bitr(genes_significativos$gene_name, fromType = "SYMBOL", toType = "ENTREZID", OrgDb = org.Hs.eg.db)$ENTREZID
}

# Usar AnnotationDbi::select para obtener los nombres de los genes (símbolos) a partir de los IDs de Entrez
gene_info <- AnnotationDbi::select(
  org.Hs.eg.db,
  keys = as.character(genes_ids),  # Asegurarse de que los IDs sean caracteres
  columns = "SYMBOL",  # Obtener los nombres de genes
  keytype = "ENTREZID"
)

# Combinar la información de los nombres de genes con log2FoldChange
genes_fc <- genes_significativos %>%
  filter(gene_name %in% gene_info$ENTREZID) %>%
  left_join(gene_info, by = c("gene_name" = "ENTREZID")) %>%
  mutate(FoldChange_direccional = sign(log2FoldChange) * 2^abs(log2FoldChange)) %>%
  dplyr::select(SYMBOL, log2FoldChange, FoldChange_direccional)  # Especificar dplyr::select

# Renombrar las columnas
genes_final <- genes_fc %>%
  rename(
    GeneSymbol = SYMBOL,
    Log2FoldChange = log2FoldChange,
    DirectionalFoldChange = FoldChange_direccional
  )

# Exportar el dataframe a un archivo CSV
write.csv(genes_final, "deSeqRes_filtrado_Fusobacterium_Nucleatum_with_FC.csv", row.names = FALSE)

# Confirmar la exportación
cat("Archivo exportado con éxito como 'deSeqRes_filtrado_Fusobacterium_Nucleatum_with_FC.csv'")
# Out:
# Loading required package: AnnotationDbi
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: 'BiocGenerics'
#
#
# The following objects are masked from 'package:stats':
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from 'package:base':
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: IRanges
#
# Loading required package: S4Vectors
#
#
# Attaching package: 'S4Vectors'
#
#
# The following objects are masked from 'package:base':
#
#     expand.grid, I, unname
#
#
#
# Attaching package: 'IRanges'
#
#
# The following object is masked from 'package:grDevices':
#
#     windows
#
#
#
#
#
# Attaching package: 'dplyr'
#
#
# The following object is masked from 'package:AnnotationDbi':
#
#     select
#
#
# The following objects are masked from 'package:IRanges':
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from 'package:S4Vectors':
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following object is masked from 'package:Biobase':
#
#     combine
#
#
# The following objects are masked from 'package:BiocGenerics':
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# 'select()' returned 1:1 mapping between keys and columns
# Archivo exportado con éxito como 'deSeqRes_filtrado_Fusobacterium_Nucleatum_with_FC.csv'
